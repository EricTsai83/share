# %%
import numpy as np
import pandas as pd
import timeit
# from numba import njit

# %%
df = pd.DataFrame({
    'first category': [0, 1, 2, 0, 1, 1, 0], 
    'y': np.arange(0, .7, .1)
})
df
# Out:
#    first category    y
# 0               0  0.0
# 1               1  0.1
# 2               2  0.2
# 3               0  0.3
# 4               1  0.4
# 5               1  0.5
# 6               0  0.6

# %%
group_means = df.groupby('first category')['y'].apply(np.mean)
group_means
# Out:
# first category
# 0    0.300000
# 1    0.333333
# 2    0.200000
# Name: y, dtype: float64

# %%
df['mean'] = df.groupby('first category')['y'].transform(np.mean)
df
# Out:
#    first category    y      mean
# 0               0  0.0  0.300000
# 1               1  0.1  0.333333
# 2               2  0.2  0.200000
# 3               0  0.3  0.300000
# 4               1  0.4  0.333333
# 5               1  0.5  0.333333
# 6               0  0.6  0.300000

# %%
n_decimals = 3
n_iters = 100

n_obs = 10**4
n_categories = 10**3

first_category = np.random.choice(n_categories, n_obs)
np.random.seed(2016)
y = np.random.normal(0, 1, n_obs)

df = pd.DataFrame({'first category': first_category,
                   'y': y})
                     
start = time.perf_counter()
grouped = df.groupby('first category')
pandas_answer = grouped.apply(np.mean)
print('time to compute group means once with Pandas: {0}'\
      .format(round(time.perf_counter() - start, n_decimals)))

start = time.perf_counter()
for i in range(n_iters):
    grouped['y'].apply(np.mean)
print('time to compute group means {0} times with Pandas: {1}'\
      .format(n_iters, round(time.perf_counter() - start, n_decimals)))
# Out:
# time to compute group means once with Pandas: 1.105
# time to compute group means 100 times with Pandas: 15.737

# %% [markdown]
# ## Faster operations without Pandas: The Groupby Class

# %%
class Groupby:
    def __init__(self, keys):
        _, self.keys_as_int = np.unique(keys, return_inverse = True)
        self.n_keys = max(self.keys_as_int) + 1
        self.set_indices()
        
    def set_indices(self):
        self.indices = [[] for i in range(self.n_keys)]
        for i, k in enumerate(self.keys_as_int):
            self.indices[k].append(i)
        self.indices = [np.array(elt) for elt in self.indices]
        
    def apply(self, function, vector, broadcast):
        if broadcast:
            result = np.zeros(len(vector))
            for idx in self.indices:
                result[idx] = function(vector[idx])
        else:
            result = np.zeros(self.n_keys)
            for k, idx in enumerate(self.indices):
                result[self.keys_as_int[k]] = function(vector[idx])

        return result

# %%
n_obs = 10**7
n_categories = 10**4

# %%
df = pd.DataFrame(np.random.randint(0, 100, size=(n_obs, 4)), columns=list('ABCD'))

# %%
df['category'] = np.random.choice(n_categories, n_obs)

# %%
df
# Out:
#           A   B   C   D  category
# 0        64  62  76   2      9424
# 1        28  86  82  11       579
# 2         5  45  15  89      8000
# 3        84  94  48  80      7576
# 4        41  88   4  80      1841
# ...      ..  ..  ..  ..       ...
# 9999995  45  96  49  21      7233
# 9999996  97  46  94   7      2529
# 9999997  64  53  50  76      9645
# 9999998  91  17  26  12      1573
# 9999999  89  89  46  16      5287
#
# [10000000 rows x 5 columns]

# %%
# %%time
grouped = Groupby(df['category'])
# Out:
# Wall time: 11.8 s

# %%
# %%time
grouped.apply(np.mean, df['A'], broadcast=True)
# Out:
# Wall time: 635 ms
# array([54.8       , 48.33333333, 41.77777778, ...,  0.        ,
#         0.        ,  0.        ])

# %%
# %%time
df.groupby('category')['A'].apply(np.mean)
# Out:
# Wall time: 5.72 s
# category
# 0       48.951196
# 1       49.814556
# 2       50.042574
# 3       49.415370
# 4       49.213402
#           ...
# 9995    49.621782
# 9996    48.583333
# 9997    49.524772
# 9998    48.487487
# 9999    48.846686
# Name: A, Length: 10000, dtype: float64

# %%
df
# Out:
#           A   B   C   D  category
# 0        64  62  76   2      9424
# 1        28  86  82  11       579
# 2         5  45  15  89      8000
# 3        84  94  48  80      7576
# 4        41  88   4  80      1841
# ...      ..  ..  ..  ..       ...
# 9999995  45  96  49  21      7233
# 9999996  97  46  94   7      2529
# 9999997  64  53  50  76      9645
# 9999998  91  17  26  12      1573
# 9999999  89  89  46  16      5287
#
# [10000000 rows x 5 columns]

# %%
n_obs = 10**7
n_categories = 10**4

# %%
df = pd.DataFrame(np.random.randint(0, 100, size=(n_obs, 4)), columns=list('ABCD'))

# %%
df['category'] = np.random.choice(n_categories, n_obs)

# %%
df
# Out:
#           A   B   C   D  category
# 0        80  26  53  87        97
# 1        74  49  39  52      9402
# 2         8   3  58  28      4818
# 3        38  60  49  88      4817
# 4        43  87  58  27      6885
# ...      ..  ..  ..  ..       ...
# 9999995  51  59   2  94      3475
# 9999996  56   8  61  39      7673
# 9999997  44  78  60  93      9701
# 9999998  72  67  18  42      9325
# 9999999  43  46  25  24      7955
#
# [10000000 rows x 5 columns]

# %%
# @njit
def groupby_apply_njit(data, func):
    """
    The first column of data is group id. The second is y and the third is x.
    """
    ngroups = int(data[-1,0])+1   # Number of groups
    nrows = data.shape[0]    # Number of rows
    reslist = []
    istart = 0
    for k in range(ngroups):
        # Find start and end rows of the group
        # (istart point to the start and iend-1 point to the end
        iend = istart + 1
        while iend < nrows and data[iend-1,0] == data[iend,0]:
            iend += 1
        # Apply the function to the numpy array in the group
        res = func(data[istart:iend,1:])
        reslist.append(np.hstack((np.array([k]), res)))
        # Move to the next group
        istart = iend
    return reslist

# %%
# %%time
df = df.sort_values(by=['category'])
# lambda x: np.mean(x, axis=0)
temp = groupby_apply(df[['category', 'A', 'B']].to_numpy(), lambda x: list(x))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <timed exec> in <module>
#
# <ipython-input-9-97d782ae7cc1> in groupby_apply(data, func)
#      13         # Apply the function to the numpy array in the group
#      14         res = func(data[istart:iend,1:])
# ---> 15         reslist.append(np.hstack((np.array([k]), res)))
#      16         # Move to the next group
#      17         istart = iend
#
# <__array_function__ internals> in hstack(*args, **kwargs)
#
# D:\Anaconda3\envs\standard\lib\site-packages\numpy\core\shape_base.py in hstack(tup)
#     341     # As a special case, dimension 0 of 1-dimensional arrays is "horizontal"
#     342     if arrs and arrs[0].ndim == 1:
# --> 343         return _nx.concatenate(arrs, 0)
#     344     else:
#     345         return _nx.concatenate(arrs, 1)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %%
df
# Out:
#           A   B   C   D  category
# 6732922  73  27  24  61         0
# 3242494  34  44  23   5         0
# 2143077  81  53  87  44         0
# 4285886  63  14  28  47         0
# 2991932  59   7  81  34         0
# ...      ..  ..  ..  ..       ...
# 8021493  72  75   4  26      9999
# 1797011  21  38  88  63      9999
# 753926   36  78  57  93      9999
# 5653644  33  81  46  89      9999
# 4950918  95  49  25  69      9999
#
# [10000000 rows x 5 columns]

# %%
temp
# Out:
# [array([0, <class 'list'>], dtype=object),
#  array([1, <class 'list'>], dtype=object),
#  array([2, <class 'list'>], dtype=object),
#  array([3, <class 'list'>], dtype=object),
#  array([4, <class 'list'>], dtype=object),
#  array([5, <class 'list'>], dtype=object),
#  array([6, <class 'list'>], dtype=object),
#  array([7, <class 'list'>], dtype=object),
#  array([8, <class 'list'>], dtype=object),
#  array([9, <class 'list'>], dtype=object),
#  array([10, <class 'list'>], dtype=object),
#  array([11, <class 'list'>], dtype=object),
#  array([12, <class 'list'>], dtype=object),
#  array([13, <class 'list'>], dtype=object),
#  array([14, <class 'list'>], dtype=object),
#  array([15, <class 'list'>], dtype=object),
#  array([16, <class 'list'>], dtype=object),
#  array([17, <class 'list'>], dtype=object),
#  array([18, <class 'list'>], dtype=object),
#  array([19, <class 'list'>], dtype=object),
#  array([20, <class 'list'>], dtype=object),
#  array([21, <class 'list'>], dtype=object),
#  array([22, <class 'list'>], dtype=object),
#  array([23, <class 'list'>], dtype=object),
#  array([24, <class 'list'>], dtype=object),
#  array([25, <class 'list'>], dtype=object),
#  array([26, <class 'list'>], dtype=object),
#  array([27, <class 'list'>], dtype=object),
#  array([28, <class 'list'>], dtype=object),
#  array([29, <class 'list'>], dtype=object),
#  array([30, <class 'list'>], dtype=object),
#  array([31, <class 'list'>], dtype=object),
#  array([32, <class 'list'>], dtype=object),
#  array([33, <class 'list'>], dtype=object),
#  array([34, <class 'list'>], dtype=object),
#  array([35, <class 'list'>], dtype=object),
#  array([36, <class 'list'>], dtype=object),
#  array([37, <class 'list'>], dtype=object),
#  array([38, <class 'list'>], dtype=object),
#  array([39, <class 'list'>], dtype=object),
#  array([40, <class 'list'>], dtype=object),
#  array([41, <class 'list'>], dtype=object),
#  array([42, <class 'list'>], dtype=object),
#  array([43, <class 'list'>], dtype=object),
#  array([44, <class 'list'>], dtype=object),
#  array([45, <class 'list'>], dtype=object),
#  array([46, <class 'list'>], dtype=object),
#  array([47, <class 'list'>], dtype=object),
#  array([48, <class 'list'>], dtype=object),
#  array([49, <class 'list'>], dtype=object),
#  array([50, <class 'list'>], dtype=object),
#  array([51, <class 'list'>], dtype=object),
#  array([52, <class 'list'>], dtype=object),
#  array([53, <class 'list'>], dtype=object),
#  array([54, <class 'list'>], dtype=object),
#  array([55, <class 'list'>], dtype=object),
#  array([56, <class 'list'>], dtype=object),
#  array([57, <class 'list'>], dtype=object),
#  array([58, <class 'list'>], dtype=object),
#  array([59, <class 'list'>], dtype=object),
#  array([60, <class 'list'>], dtype=object),
#  array([61, <class 'list'>], dtype=object),
#  array([62, <class 'list'>], dtype=object),
#  array([63, <class 'list'>], dtype=object),
#  array([64, <class 'list'>], dtype=object),
#  array([65, <class 'list'>], dtype=object),
#  array([66, <class 'list'>], dtype=object),
#  array([67, <class 'list'>], dtype=object),
#  array([68, <class 'list'>], dtype=object),
#  array([69, <class 'list'>], dtype=object),
#  array([70, <class 'list'>], dtype=object),
#  array([71, <class 'list'>], dtype=object),
#  array([72, <class 'list'>], dtype=object),
#  array([73, <class 'list'>], dtype=object),
#  array([74, <class 'list'>], dtype=object),
#  array([75, <class 'list'>], dtype=object),
#  array([76, <class 'list'>], dtype=object),
#  array([77, <class 'list'>], dtype=object),
#  array([78, <class 'list'>], dtype=object),
#  array([79, <class 'list'>], dtype=object),
#  array([80, <class 'list'>], dtype=object),
#  array([81, <class 'list'>], dtype=object),
#  array([82, <class 'list'>], dtype=object),
#  array([83, <class 'list'>], dtype=object),
#  array([84, <class 'list'>], dtype=object),
#  array([85, <class 'list'>], dtype=object),
#  array([86, <class 'list'>], dtype=object),
#  array([87, <class 'list'>], dtype=object),
#  array([88, <class 'list'>], dtype=object),
#  array([89, <class 'list'>], dtype=object),
#  array([90, <class 'list'>], dtype=object),
#  array([91, <class 'list'>], dtype=object),
#  array([92, <class 'list'>], dtype=object),
#  array([93, <class 'list'>], dtype=object),
#  array([94, <class 'list'>], dtype=object),
#  array([95, <class 'list'>], dtype=object),
#  array([96, <class 'list'>], dtype=object),
#  array([97, <class 'list'>], dtype=object),
#  array([98, <class 'list'>], dtype=object),
#  array([99, <class 'list'>], dtype=object),
#  array([100, <class 'list'>], dtype=object),
#  array([101, <class 'list'>], dtype=object),
#  array([102, <class 'list'>], dtype=object),
#  array([103, <class 'list'>], dtype=object),
#  array([104, <class 'list'>], dtype=object),
#  array([105, <class 'list'>], dtype=object),
#  array([106, <class 'list'>], dtype=object),
#  array([107, <class 'list'>], dtype=object),
#  array([108, <class 'list'>], dtype=object),
#  array([109, <class 'list'>], dtype=object),
#  array([110, <class 'list'>], dtype=object),
#  array([111, <class 'list'>], dtype=object),
#  array([112, <class 'list'>], dtype=object),
#  array([113, <class 'list'>], dtype=object),
#  array([114, <class 'list'>], dtype=object),
#  array([115, <class 'list'>], dtype=object),
#  array([116, <class 'list'>], dtype=object),
#  array([117, <class 'list'>], dtype=object),
#  array([118, <class 'list'>], dtype=object),
#  array([119, <class 'list'>], dtype=object),
#  array([120, <class 'list'>], dtype=object),
#  array([121, <class 'list'>], dtype=object),
#  array([122, <class 'list'>], dtype=object),
#  array([123, <class 'list'>], dtype=object),
#  array([124, <class 'list'>], dtype=object),
#  array([125, <class 'list'>], dtype=object),
#  array([126, <class 'list'>], dtype=object),
#  array([127, <class 'list'>], dtype=object),
#  array([128, <class 'list'>], dtype=object),
#  array([129, <class 'list'>], dtype=object),
#  array([130, <class 'list'>], dtype=object),
#  array([131, <class 'list'>], dtype=object),
#  array([132, <class 'list'>], dtype=object),
#  array([133, <class 'list'>], dtype=object),
#  array([134, <class 'list'>], dtype=object),
#  array([135, <class 'list'>], dtype=object),
#  array([136, <class 'list'>], dtype=object),
#  array([137, <class 'list'>], dtype=object),
#  array([138, <class 'list'>], dtype=object),
#  array([139, <class 'list'>], dtype=object),
#  array([140, <class 'list'>], dtype=object),
#  array([141, <class 'list'>], dtype=object),
#  array([142, <class 'list'>], dtype=object),
#  array([143, <class 'list'>], dtype=object),
#  array([144, <class 'list'>], dtype=object),
#  array([145, <class 'list'>], dtype=object),
#  array([146, <class 'list'>], dtype=object),
#  array([147, <class 'list'>], dtype=object),
#  array([148, <class 'list'>], dtype=object),
#  array([149, <class 'list'>], dtype=object),
#  array([150, <class 'list'>], dtype=object),
#  array([151, <class 'list'>], dtype=object),
#  array([152, <class 'list'>], dtype=object),
#  array([153, <class 'list'>], dtype=object),
#  array([154, <class 'list'>], dtype=object),
#  array([155, <class 'list'>], dtype=object),
#  array([156, <class 'list'>], dtype=object),
#  array([157, <class 'list'>], dtype=object),
#  array([158, <class 'list'>], dtype=object),
#  array([159, <class 'list'>], dtype=object),
#  array([160, <class 'list'>], dtype=object),
#  array([161, <class 'list'>], dtype=object),
#  array([162, <class 'list'>], dtype=object),
#  array([163, <class 'list'>], dtype=object),
#  array([164, <class 'list'>], dtype=object),
#  array([165, <class 'list'>], dtype=object),
#  array([166, <class 'list'>], dtype=object),
#  array([167, <class 'list'>], dtype=object),
#  array([168, <class 'list'>], dtype=object),
#  array([169, <class 'list'>], dtype=object),
#  array([170, <class 'list'>], dtype=object),
#  array([171, <class 'list'>], dtype=object),
#  array([172, <class 'list'>], dtype=object),
#  array([173, <class 'list'>], dtype=object),
#  array([174, <class 'list'>], dtype=object),
#  array([175, <class 'list'>], dtype=object),
#  array([176, <class 'list'>], dtype=object),
#  array([177, <class 'list'>], dtype=object),
#  array([178, <class 'list'>], dtype=object),
#  array([179, <class 'list'>], dtype=object),
#  array([180, <class 'list'>], dtype=object),
#  array([181, <class 'list'>], dtype=object),
#  array([182, <class 'list'>], dtype=object),
#  array([183, <class 'list'>], dtype=object),
#  array([184, <class 'list'>], dtype=object),
#  array([185, <class 'list'>], dtype=object),
#  array([186, <class 'list'>], dtype=object),
#  array([187, <class 'list'>], dtype=object),
#  array([188, <class 'list'>], dtype=object),
#  array([189, <class 'list'>], dtype=object),
#  array([190, <class 'list'>], dtype=object),
#  array([191, <class 'list'>], dtype=object),
#  array([192, <class 'list'>], dtype=object),
#  array([193, <class 'list'>], dtype=object),
#  array([194, <class 'list'>], dtype=object),
#  array([195, <class 'list'>], dtype=object),
#  array([196, <class 'list'>], dtype=object),
#  array([197, <class 'list'>], dtype=object),
#  array([198, <class 'list'>], dtype=object),
#  array([199, <class 'list'>], dtype=object),
#  array([200, <class 'list'>], dtype=object),
#  array([201, <class 'list'>], dtype=object),
#  array([202, <class 'list'>], dtype=object),
#  array([203, <class 'list'>], dtype=object),
#  array([204, <class 'list'>], dtype=object),
#  array([205, <class 'list'>], dtype=object),
#  array([206, <class 'list'>], dtype=object),
#  array([207, <class 'list'>], dtype=object),
#  array([208, <class 'list'>], dtype=object),
#  array([209, <class 'list'>], dtype=object),
#  array([210, <class 'list'>], dtype=object),
#  array([211, <class 'list'>], dtype=object),
#  array([212, <class 'list'>], dtype=object),
#  array([213, <class 'list'>], dtype=object),
#  array([214, <class 'list'>], dtype=object),
#  array([215, <class 'list'>], dtype=object),
#  array([216, <class 'list'>], dtype=object),
#  array([217, <class 'list'>], dtype=object),
#  array([218, <class 'list'>], dtype=object),
#  array([219, <class 'list'>], dtype=object),
#  array([220, <class 'list'>], dtype=object),
#  array([221, <class 'list'>], dtype=object),
#  array([222, <class 'list'>], dtype=object),
#  array([223, <class 'list'>], dtype=object),
#  array([224, <class 'list'>], dtype=object),
#  array([225, <class 'list'>], dtype=object),
#  array([226, <class 'list'>], dtype=object),
#  array([227, <class 'list'>], dtype=object),
#  array([228, <class 'list'>], dtype=object),
#  array([229, <class 'list'>], dtype=object),
#  array([230, <class 'list'>], dtype=object),
#  array([231, <class 'list'>], dtype=object),
#  array([232, <class 'list'>], dtype=object),
#  array([233, <class 'list'>], dtype=object),
#  array([234, <class 'list'>], dtype=object),
#  array([235, <class 'list'>], dtype=object),
#  array([236, <class 'list'>], dtype=object),
#  array([237, <class 'list'>], dtype=object),
#  array([238, <class 'list'>], dtype=object),
#  array([239, <class 'list'>], dtype=object),
#  array([240, <class 'list'>], dtype=object),
#  array([241, <class 'list'>], dtype=object),
#  array([242, <class 'list'>], dtype=object),
#  array([243, <class 'list'>], dtype=object),
#  array([244, <class 'list'>], dtype=object),
#  array([245, <class 'list'>], dtype=object),
#  array([246, <class 'list'>], dtype=object),
#  array([247, <class 'list'>], dtype=object),
#  array([248, <class 'list'>], dtype=object),
#  array([249, <class 'list'>], dtype=object),
#  array([250, <class 'list'>], dtype=object),
#  array([251, <class 'list'>], dtype=object),
#  array([252, <class 'list'>], dtype=object),
#  array([253, <class 'list'>], dtype=object),
#  array([254, <class 'list'>], dtype=object),
#  array([255, <class 'list'>], dtype=object),
#  array([256, <class 'list'>], dtype=object),
#  array([257, <class 'list'>], dtype=object),
#  array([258, <class 'list'>], dtype=object),
#  array([259, <class 'list'>], dtype=object),
#  array([260, <class 'list'>], dtype=object),
#  array([261, <class 'list'>], dtype=object),
#  array([262, <class 'list'>], dtype=object),
#  array([263, <class 'list'>], dtype=object),
#  array([264, <class 'list'>], dtype=object),
#  array([265, <class 'list'>], dtype=object),
#  array([266, <class 'list'>], dtype=object),
#  array([267, <class 'list'>], dtype=object),
#  array([268, <class 'list'>], dtype=object),
#  array([269, <class 'list'>], dtype=object),
#  array([270, <class 'list'>], dtype=object),
#  array([271, <class 'list'>], dtype=object),
#  array([272, <class 'list'>], dtype=object),
#  array([273, <class 'list'>], dtype=object),
#  array([274, <class 'list'>], dtype=object),
#  array([275, <class 'list'>], dtype=object),
#  array([276, <class 'list'>], dtype=object),
#  array([277, <class 'list'>], dtype=object),
#  array([278, <class 'list'>], dtype=object),
#  array([279, <class 'list'>], dtype=object),
#  array([280, <class 'list'>], dtype=object),
#  array([281, <class 'list'>], dtype=object),
#  array([282, <class 'list'>], dtype=object),
#  array([283, <class 'list'>], dtype=object),
#  array([284, <class 'list'>], dtype=object),
#  array([285, <class 'list'>], dtype=object),
#  array([286, <class 'list'>], dtype=object),
#  array([287, <class 'list'>], dtype=object),
#  array([288, <class 'list'>], dtype=object),
#  array([289, <class 'list'>], dtype=object),
#  array([290, <class 'list'>], dtype=object),
#  array([291, <class 'list'>], dtype=object),
#  array([292, <class 'list'>], dtype=object),
#  array([293, <class 'list'>], dtype=object),
#  array([294, <class 'list'>], dtype=object),
#  array([295, <class 'list'>], dtype=object),
#  array([296, <class 'list'>], dtype=object),
#  array([297, <class 'list'>], dtype=object),
#  array([298, <class 'list'>], dtype=object),
#  array([299, <class 'list'>], dtype=object),
#  array([300, <class 'list'>], dtype=object),
#  array([301, <class 'list'>], dtype=object),
#  array([302, <class 'list'>], dtype=object),
#  array([303, <class 'list'>], dtype=object),
#  array([304, <class 'list'>], dtype=object),
#  array([305, <class 'list'>], dtype=object),
#  array([306, <class 'list'>], dtype=object),
#  array([307, <class 'list'>], dtype=object),
#  array([308, <class 'list'>], dtype=object),
#  array([309, <class 'list'>], dtype=object),
#  array([310, <class 'list'>], dtype=object),
#  array([311, <class 'list'>], dtype=object),
#  array([312, <class 'list'>], dtype=object),
#  array([313, <class 'list'>], dtype=object),
#  array([314, <class 'list'>], dtype=object),
#  array([315, <class 'list'>], dtype=object),
#  array([316, <class 'list'>], dtype=object),
#  array([317, <class 'list'>], dtype=object),
#  array([318, <class 'list'>], dtype=object),
#  array([319, <class 'list'>], dtype=object),
#  array([320, <class 'list'>], dtype=object),
#  array([321, <class 'list'>], dtype=object),
#  array([322, <class 'list'>], dtype=object),
#  array([323, <class 'list'>], dtype=object),
#  array([324, <class 'list'>], dtype=object),
#  array([325, <class 'list'>], dtype=object),
#  array([326, <class 'list'>], dtype=object),
#  array([327, <class 'list'>], dtype=object),
#  array([328, <class 'list'>], dtype=object),
#  array([329, <class 'list'>], dtype=object),
#  array([330, <class 'list'>], dtype=object),
#  array([331, <class 'list'>], dtype=object),
#  array([332, <class 'list'>], dtype=object),
#  array([333, <class 'list'>], dtype=object),
#  array([334, <class 'list'>], dtype=object),
#  array([335, <class 'list'>], dtype=object),
#  array([336, <class 'list'>], dtype=object),
#  array([337, <class 'list'>], dtype=object),
#  array([338, <class 'list'>], dtype=object),
#  array([339, <class 'list'>], dtype=object),
#  array([340, <class 'list'>], dtype=object),
#  array([341, <class 'list'>], dtype=object),
#  array([342, <class 'list'>], dtype=object),
#  array([343, <class 'list'>], dtype=object),
#  array([344, <class 'list'>], dtype=object),
#  array([345, <class 'list'>], dtype=object),
#  array([346, <class 'list'>], dtype=object),
#  array([347, <class 'list'>], dtype=object),
#  array([348, <class 'list'>], dtype=object),
#  array([349, <class 'list'>], dtype=object),
#  array([350, <class 'list'>], dtype=object),
#  array([351, <class 'list'>], dtype=object),
#  array([352, <class 'list'>], dtype=object),
#  array([353, <class 'list'>], dtype=object),
#  array([354, <class 'list'>], dtype=object),
#  array([355, <class 'list'>], dtype=object),
#  array([356, <class 'list'>], dtype=object),
#  array([357, <class 'list'>], dtype=object),
#  array([358, <class 'list'>], dtype=object),
#  array([359, <class 'list'>], dtype=object),
#  array([360, <class 'list'>], dtype=object),
#  array([361, <class 'list'>], dtype=object),
#  array([362, <class 'list'>], dtype=object),
#  array([363, <class 'list'>], dtype=object),
#  array([364, <class 'list'>], dtype=object),
#  array([365, <class 'list'>], dtype=object),
#  array([366, <class 'list'>], dtype=object),
#  array([367, <class 'list'>], dtype=object),
#  array([368, <class 'list'>], dtype=object),
#  array([369, <class 'list'>], dtype=object),
#  array([370, <class 'list'>], dtype=object),
#  array([371, <class 'list'>], dtype=object),
#  array([372, <class 'list'>], dtype=object),
#  array([373, <class 'list'>], dtype=object),
#  array([374, <class 'list'>], dtype=object),
#  array([375, <class 'list'>], dtype=object),
#  array([376, <class 'list'>], dtype=object),
#  array([377, <class 'list'>], dtype=object),
#  array([378, <class 'list'>], dtype=object),
#  array([379, <class 'list'>], dtype=object),
#  array([380, <class 'list'>], dtype=object),
#  array([381, <class 'list'>], dtype=object),
#  array([382, <class 'list'>], dtype=object),
#  array([383, <class 'list'>], dtype=object),
#  array([384, <class 'list'>], dtype=object),
#  array([385, <class 'list'>], dtype=object),
#  array([386, <class 'list'>], dtype=object),
#  array([387, <class 'list'>], dtype=object),
#  array([388, <class 'list'>], dtype=object),
#  array([389, <class 'list'>], dtype=object),
#  array([390, <class 'list'>], dtype=object),
#  array([391, <class 'list'>], dtype=object),
#  array([392, <class 'list'>], dtype=object),
#  array([393, <class 'list'>], dtype=object),
#  array([394, <class 'list'>], dtype=object),
#  array([395, <class 'list'>], dtype=object),
#  array([396, <class 'list'>], dtype=object),
#  array([397, <class 'list'>], dtype=object),
#  array([398, <class 'list'>], dtype=object),
#  array([399, <class 'list'>], dtype=object),
#  array([400, <class 'list'>], dtype=object),
#  array([401, <class 'list'>], dtype=object),
#  array([402, <class 'list'>], dtype=object),
#  array([403, <class 'list'>], dtype=object),
#  array([404, <class 'list'>], dtype=object),
#  array([405, <class 'list'>], dtype=object),
#  array([406, <class 'list'>], dtype=object),
#  array([407, <class 'list'>], dtype=object),
#  array([408, <class 'list'>], dtype=object),
#  array([409, <class 'list'>], dtype=object),
#  array([410, <class 'list'>], dtype=object),
#  array([411, <class 'list'>], dtype=object),
#  array([412, <class 'list'>], dtype=object),
#  array([413, <class 'list'>], dtype=object),
#  array([414, <class 'list'>], dtype=object),
#  array([415, <class 'list'>], dtype=object),
#  array([416, <class 'list'>], dtype=object),
#  array([417, <class 'list'>], dtype=object),
#  array([418, <class 'list'>], dtype=object),
#  array([419, <class 'list'>], dtype=object),
#  array([420, <class 'list'>], dtype=object),
#  array([421, <class 'list'>], dtype=object),
#  array([422, <class 'list'>], dtype=object),
#  array([423, <class 'list'>], dtype=object),
#  array([424, <class 'list'>], dtype=object),
#  array([425, <class 'list'>], dtype=object),
#  array([426, <class 'list'>], dtype=object),
#  array([427, <class 'list'>], dtype=object),
#  array([428, <class 'list'>], dtype=object),
#  array([429, <class 'list'>], dtype=object),
#  array([430, <class 'list'>], dtype=object),
#  array([431, <class 'list'>], dtype=object),
#  array([432, <class 'list'>], dtype=object),
#  array([433, <class 'list'>], dtype=object),
#  array([434, <class 'list'>], dtype=object),
#  array([435, <class 'list'>], dtype=object),
#  array([436, <class 'list'>], dtype=object),
#  array([437, <class 'list'>], dtype=object),
#  array([438, <class 'list'>], dtype=object),
#  array([439, <class 'list'>], dtype=object),
#  array([440, <class 'list'>], dtype=object),
#  array([441, <class 'list'>], dtype=object),
#  array([442, <class 'list'>], dtype=object),
#  array([443, <class 'list'>], dtype=object),
#  array([444, <class 'list'>], dtype=object),
#  array([445, <class 'list'>], dtype=object),
#  array([446, <class 'list'>], dtype=object),
#  array([447, <class 'list'>], dtype=object),
#  array([448, <class 'list'>], dtype=object),
#  array([449, <class 'list'>], dtype=object),
#  array([450, <class 'list'>], dtype=object),
#  array([451, <class 'list'>], dtype=object),
#  array([452, <class 'list'>], dtype=object),
#  array([453, <class 'list'>], dtype=object),
#  array([454, <class 'list'>], dtype=object),
#  array([455, <class 'list'>], dtype=object),
#  array([456, <class 'list'>], dtype=object),
#  array([457, <class 'list'>], dtype=object),
#  array([458, <class 'list'>], dtype=object),
#  array([459, <class 'list'>], dtype=object),
#  array([460, <class 'list'>], dtype=object),
#  array([461, <class 'list'>], dtype=object),
#  array([462, <class 'list'>], dtype=object),
#  array([463, <class 'list'>], dtype=object),
#  array([464, <class 'list'>], dtype=object),
#  array([465, <class 'list'>], dtype=object),
#  array([466, <class 'list'>], dtype=object),
#  array([467, <class 'list'>], dtype=object),
#  array([468, <class 'list'>], dtype=object),
#  array([469, <class 'list'>], dtype=object),
#  array([470, <class 'list'>], dtype=object),
#  array([471, <class 'list'>], dtype=object),
#  array([472, <class 'list'>], dtype=object),
#  array([473, <class 'list'>], dtype=object),
#  array([474, <class 'list'>], dtype=object),
#  array([475, <class 'list'>], dtype=object),
#  array([476, <class 'list'>], dtype=object),
#  array([477, <class 'list'>], dtype=object),
#  array([478, <class 'list'>], dtype=object),
#  array([479, <class 'list'>], dtype=object),
#  array([480, <class 'list'>], dtype=object),
#  array([481, <class 'list'>], dtype=object),
#  array([482, <class 'list'>], dtype=object),
#  array([483, <class 'list'>], dtype=object),
#  array([484, <class 'list'>], dtype=object),
#  array([485, <class 'list'>], dtype=object),
#  array([486, <class 'list'>], dtype=object),
#  array([487, <class 'list'>], dtype=object),
#  array([488, <class 'list'>], dtype=object),
#  array([489, <class 'list'>], dtype=object),
#  array([490, <class 'list'>], dtype=object),
#  array([491, <class 'list'>], dtype=object),
#  array([492, <class 'list'>], dtype=object),
#  array([493, <class 'list'>], dtype=object),
#  array([494, <class 'list'>], dtype=object),
#  array([495, <class 'list'>], dtype=object),
#  array([496, <class 'list'>], dtype=object),
#  array([497, <class 'list'>], dtype=object),
#  array([498, <class 'list'>], dtype=object),
#  array([499, <class 'list'>], dtype=object),
#  array([500, <class 'list'>], dtype=object),
#  array([501, <class 'list'>], dtype=object),
#  array([502, <class 'list'>], dtype=object),
#  array([503, <class 'list'>], dtype=object),
#  array([504, <class 'list'>], dtype=object),
#  array([505, <class 'list'>], dtype=object),
#  array([506, <class 'list'>], dtype=object),
#  array([507, <class 'list'>], dtype=object),
#  array([508, <class 'list'>], dtype=object),
#  array([509, <class 'list'>], dtype=object),
#  array([510, <class 'list'>], dtype=object),
#  array([511, <class 'list'>], dtype=object),
#  array([512, <class 'list'>], dtype=object),
#  array([513, <class 'list'>], dtype=object),
#  array([514, <class 'list'>], dtype=object),
#  array([515, <class 'list'>], dtype=object),
#  array([516, <class 'list'>], dtype=object),
#  array([517, <class 'list'>], dtype=object),
#  array([518, <class 'list'>], dtype=object),
#  array([519, <class 'list'>], dtype=object),
#  array([520, <class 'list'>], dtype=object),
#  array([521, <class 'list'>], dtype=object),
#  array([522, <class 'list'>], dtype=object),
#  array([523, <class 'list'>], dtype=object),
#  array([524, <class 'list'>], dtype=object),
#  array([525, <class 'list'>], dtype=object),
#  array([526, <class 'list'>], dtype=object),
#  array([527, <class 'list'>], dtype=object),
#  array([528, <class 'list'>], dtype=object),
#  array([529, <class 'list'>], dtype=object),
#  array([530, <class 'list'>], dtype=object),
#  array([531, <class 'list'>], dtype=object),
#  array([532, <class 'list'>], dtype=object),
#  array([533, <class 'list'>], dtype=object),
#  array([534, <class 'list'>], dtype=object),
#  array([535, <class 'list'>], dtype=object),
#  array([536, <class 'list'>], dtype=object),
#  array([537, <class 'list'>], dtype=object),
#  array([538, <class 'list'>], dtype=object),
#  array([539, <class 'list'>], dtype=object),
#  array([540, <class 'list'>], dtype=object),
#  array([541, <class 'list'>], dtype=object),
#  array([542, <class 'list'>], dtype=object),
#  array([543, <class 'list'>], dtype=object),
#  array([544, <class 'list'>], dtype=object),
#  array([545, <class 'list'>], dtype=object),
#  array([546, <class 'list'>], dtype=object),
#  array([547, <class 'list'>], dtype=object),
#  array([548, <class 'list'>], dtype=object),
#  array([549, <class 'list'>], dtype=object),
#  array([550, <class 'list'>], dtype=object),
#  array([551, <class 'list'>], dtype=object),
#  array([552, <class 'list'>], dtype=object),
#  array([553, <class 'list'>], dtype=object),
#  array([554, <class 'list'>], dtype=object),
#  array([555, <class 'list'>], dtype=object),
#  array([556, <class 'list'>], dtype=object),
#  array([557, <class 'list'>], dtype=object),
#  array([558, <class 'list'>], dtype=object),
#  array([559, <class 'list'>], dtype=object),
#  array([560, <class 'list'>], dtype=object),
#  array([561, <class 'list'>], dtype=object),
#  array([562, <class 'list'>], dtype=object),
#  array([563, <class 'list'>], dtype=object),
#  array([564, <class 'list'>], dtype=object),
#  array([565, <class 'list'>], dtype=object),
#  array([566, <class 'list'>], dtype=object),
#  array([567, <class 'list'>], dtype=object),
#  array([568, <class 'list'>], dtype=object),
#  array([569, <class 'list'>], dtype=object),
#  array([570, <class 'list'>], dtype=object),
#  array([571, <class 'list'>], dtype=object),
#  array([572, <class 'list'>], dtype=object),
#  array([573, <class 'list'>], dtype=object),
#  array([574, <class 'list'>], dtype=object),
#  array([575, <class 'list'>], dtype=object),
#  array([576, <class 'list'>], dtype=object),
#  array([577, <class 'list'>], dtype=object),
#  array([578, <class 'list'>], dtype=object),
#  array([579, <class 'list'>], dtype=object),
#  array([580, <class 'list'>], dtype=object),
#  array([581, <class 'list'>], dtype=object),
#  array([582, <class 'list'>], dtype=object),
#  array([583, <class 'list'>], dtype=object),
#  array([584, <class 'list'>], dtype=object),
#  array([585, <class 'list'>], dtype=object),
#  array([586, <class 'list'>], dtype=object),
#  array([587, <class 'list'>], dtype=object),
#  array([588, <class 'list'>], dtype=object),
#  array([589, <class 'list'>], dtype=object),
#  array([590, <class 'list'>], dtype=object),
#  array([591, <class 'list'>], dtype=object),
#  array([592, <class 'list'>], dtype=object),
#  array([593, <class 'list'>], dtype=object),
#  array([594, <class 'list'>], dtype=object),
#  array([595, <class 'list'>], dtype=object),
#  array([596, <class 'list'>], dtype=object),
#  array([597, <class 'list'>], dtype=object),
#  array([598, <class 'list'>], dtype=object),
#  array([599, <class 'list'>], dtype=object),
#  array([600, <class 'list'>], dtype=object),
#  array([601, <class 'list'>], dtype=object),
#  array([602, <class 'list'>], dtype=object),
#  array([603, <class 'list'>], dtype=object),
#  array([604, <class 'list'>], dtype=object),
#  array([605, <class 'list'>], dtype=object),
#  array([606, <class 'list'>], dtype=object),
#  array([607, <class 'list'>], dtype=object),
#  array([608, <class 'list'>], dtype=object),
#  array([609, <class 'list'>], dtype=object),
#  array([610, <class 'list'>], dtype=object),
#  array([611, <class 'list'>], dtype=object),
#  array([612, <class 'list'>], dtype=object),
#  array([613, <class 'list'>], dtype=object),
#  array([614, <class 'list'>], dtype=object),
#  array([615, <class 'list'>], dtype=object),
#  array([616, <class 'list'>], dtype=object),
#  array([617, <class 'list'>], dtype=object),
#  array([618, <class 'list'>], dtype=object),
#  array([619, <class 'list'>], dtype=object),
#  array([620, <class 'list'>], dtype=object),
#  array([621, <class 'list'>], dtype=object),
#  array([622, <class 'list'>], dtype=object),
#  array([623, <class 'list'>], dtype=object),
#  array([624, <class 'list'>], dtype=object),
#  array([625, <class 'list'>], dtype=object),
#  array([626, <class 'list'>], dtype=object),
#  array([627, <class 'list'>], dtype=object),
#  array([628, <class 'list'>], dtype=object),
#  array([629, <class 'list'>], dtype=object),
#  array([630, <class 'list'>], dtype=object),
#  array([631, <class 'list'>], dtype=object),
#  array([632, <class 'list'>], dtype=object),
#  array([633, <class 'list'>], dtype=object),
#  array([634, <class 'list'>], dtype=object),
#  array([635, <class 'list'>], dtype=object),
#  array([636, <class 'list'>], dtype=object),
#  array([637, <class 'list'>], dtype=object),
#  array([638, <class 'list'>], dtype=object),
#  array([639, <class 'list'>], dtype=object),
#  array([640, <class 'list'>], dtype=object),
#  array([641, <class 'list'>], dtype=object),
#  array([642, <class 'list'>], dtype=object),
#  array([643, <class 'list'>], dtype=object),
#  array([644, <class 'list'>], dtype=object),
#  array([645, <class 'list'>], dtype=object),
#  array([646, <class 'list'>], dtype=object),
#  array([647, <class 'list'>], dtype=object),
#  array([648, <class 'list'>], dtype=object),
#  array([649, <class 'list'>], dtype=object),
#  array([650, <class 'list'>], dtype=object),
#  array([651, <class 'list'>], dtype=object),
#  array([652, <class 'list'>], dtype=object),
#  array([653, <class 'list'>], dtype=object),
#  array([654, <class 'list'>], dtype=object),
#  array([655, <class 'list'>], dtype=object),
#  array([656, <class 'list'>], dtype=object),
#  array([657, <class 'list'>], dtype=object),
#  array([658, <class 'list'>], dtype=object),
#  array([659, <class 'list'>], dtype=object),
#  array([660, <class 'list'>], dtype=object),
#  array([661, <class 'list'>], dtype=object),
#  array([662, <class 'list'>], dtype=object),
#  array([663, <class 'list'>], dtype=object),
#  array([664, <class 'list'>], dtype=object),
#  array([665, <class 'list'>], dtype=object),
#  array([666, <class 'list'>], dtype=object),
#  array([667, <class 'list'>], dtype=object),
#  array([668, <class 'list'>], dtype=object),
#  array([669, <class 'list'>], dtype=object),
#  array([670, <class 'list'>], dtype=object),
#  array([671, <class 'list'>], dtype=object),
#  array([672, <class 'list'>], dtype=object),
#  array([673, <class 'list'>], dtype=object),
#  array([674, <class 'list'>], dtype=object),
#  array([675, <class 'list'>], dtype=object),
#  array([676, <class 'list'>], dtype=object),
#  array([677, <class 'list'>], dtype=object),
#  array([678, <class 'list'>], dtype=object),
#  array([679, <class 'list'>], dtype=object),
#  array([680, <class 'list'>], dtype=object),
#  array([681, <class 'list'>], dtype=object),
#  array([682, <class 'list'>], dtype=object),
#  array([683, <class 'list'>], dtype=object),
#  array([684, <class 'list'>], dtype=object),
#  array([685, <class 'list'>], dtype=object),
#  array([686, <class 'list'>], dtype=object),
#  array([687, <class 'list'>], dtype=object),
#  array([688, <class 'list'>], dtype=object),
#  array([689, <class 'list'>], dtype=object),
#  array([690, <class 'list'>], dtype=object),
#  array([691, <class 'list'>], dtype=object),
#  array([692, <class 'list'>], dtype=object),
#  array([693, <class 'list'>], dtype=object),
#  array([694, <class 'list'>], dtype=object),
#  array([695, <class 'list'>], dtype=object),
#  array([696, <class 'list'>], dtype=object),
#  array([697, <class 'list'>], dtype=object),
#  array([698, <class 'list'>], dtype=object),
#  array([699, <class 'list'>], dtype=object),
#  array([700, <class 'list'>], dtype=object),
#  array([701, <class 'list'>], dtype=object),
#  array([702, <class 'list'>], dtype=object),
#  array([703, <class 'list'>], dtype=object),
#  array([704, <class 'list'>], dtype=object),
#  array([705, <class 'list'>], dtype=object),
#  array([706, <class 'list'>], dtype=object),
#  array([707, <class 'list'>], dtype=object),
#  array([708, <class 'list'>], dtype=object),
#  array([709, <class 'list'>], dtype=object),
#  array([710, <class 'list'>], dtype=object),
#  array([711, <class 'list'>], dtype=object),
#  array([712, <class 'list'>], dtype=object),
#  array([713, <class 'list'>], dtype=object),
#  array([714, <class 'list'>], dtype=object),
#  array([715, <class 'list'>], dtype=object),
#  array([716, <class 'list'>], dtype=object),
#  array([717, <class 'list'>], dtype=object),
#  array([718, <class 'list'>], dtype=object),
#  array([719, <class 'list'>], dtype=object),
#  array([720, <class 'list'>], dtype=object),
#  array([721, <class 'list'>], dtype=object),
#  array([722, <class 'list'>], dtype=object),
#  array([723, <class 'list'>], dtype=object),
#  array([724, <class 'list'>], dtype=object),
#  array([725, <class 'list'>], dtype=object),
#  array([726, <class 'list'>], dtype=object),
#  array([727, <class 'list'>], dtype=object),
#  array([728, <class 'list'>], dtype=object),
#  array([729, <class 'list'>], dtype=object),
#  array([730, <class 'list'>], dtype=object),
#  array([731, <class 'list'>], dtype=object),
#  array([732, <class 'list'>], dtype=object),
#  array([733, <class 'list'>], dtype=object),
#  array([734, <class 'list'>], dtype=object),
#  array([735, <class 'list'>], dtype=object),
#  array([736, <class 'list'>], dtype=object),
#  array([737, <class 'list'>], dtype=object),
#  array([738, <class 'list'>], dtype=object),
#  array([739, <class 'list'>], dtype=object),
#  array([740, <class 'list'>], dtype=object),
#  array([741, <class 'list'>], dtype=object),
#  array([742, <class 'list'>], dtype=object),
#  array([743, <class 'list'>], dtype=object),
#  array([744, <class 'list'>], dtype=object),
#  array([745, <class 'list'>], dtype=object),
#  array([746, <class 'list'>], dtype=object),
#  array([747, <class 'list'>], dtype=object),
#  array([748, <class 'list'>], dtype=object),
#  array([749, <class 'list'>], dtype=object),
#  array([750, <class 'list'>], dtype=object),
#  array([751, <class 'list'>], dtype=object),
#  array([752, <class 'list'>], dtype=object),
#  array([753, <class 'list'>], dtype=object),
#  array([754, <class 'list'>], dtype=object),
#  array([755, <class 'list'>], dtype=object),
#  array([756, <class 'list'>], dtype=object),
#  array([757, <class 'list'>], dtype=object),
#  array([758, <class 'list'>], dtype=object),
#  array([759, <class 'list'>], dtype=object),
#  array([760, <class 'list'>], dtype=object),
#  array([761, <class 'list'>], dtype=object),
#  array([762, <class 'list'>], dtype=object),
#  array([763, <class 'list'>], dtype=object),
#  array([764, <class 'list'>], dtype=object),
#  array([765, <class 'list'>], dtype=object),
#  array([766, <class 'list'>], dtype=object),
#  array([767, <class 'list'>], dtype=object),
#  array([768, <class 'list'>], dtype=object),
#  array([769, <class 'list'>], dtype=object),
#  array([770, <class 'list'>], dtype=object),
#  array([771, <class 'list'>], dtype=object),
#  array([772, <class 'list'>], dtype=object),
#  array([773, <class 'list'>], dtype=object),
#  array([774, <class 'list'>], dtype=object),
#  array([775, <class 'list'>], dtype=object),
#  array([776, <class 'list'>], dtype=object),
#  array([777, <class 'list'>], dtype=object),
#  array([778, <class 'list'>], dtype=object),
#  array([779, <class 'list'>], dtype=object),
#  array([780, <class 'list'>], dtype=object),
#  array([781, <class 'list'>], dtype=object),
#  array([782, <class 'list'>], dtype=object),
#  array([783, <class 'list'>], dtype=object),
#  array([784, <class 'list'>], dtype=object),
#  array([785, <class 'list'>], dtype=object),
#  array([786, <class 'list'>], dtype=object),
#  array([787, <class 'list'>], dtype=object),
#  array([788, <class 'list'>], dtype=object),
#  array([789, <class 'list'>], dtype=object),
#  array([790, <class 'list'>], dtype=object),
#  array([791, <class 'list'>], dtype=object),
#  array([792, <class 'list'>], dtype=object),
#  array([793, <class 'list'>], dtype=object),
#  array([794, <class 'list'>], dtype=object),
#  array([795, <class 'list'>], dtype=object),
#  array([796, <class 'list'>], dtype=object),
#  array([797, <class 'list'>], dtype=object),
#  array([798, <class 'list'>], dtype=object),
#  array([799, <class 'list'>], dtype=object),
#  array([800, <class 'list'>], dtype=object),
#  array([801, <class 'list'>], dtype=object),
#  array([802, <class 'list'>], dtype=object),
#  array([803, <class 'list'>], dtype=object),
#  array([804, <class 'list'>], dtype=object),
#  array([805, <class 'list'>], dtype=object),
#  array([806, <class 'list'>], dtype=object),
#  array([807, <class 'list'>], dtype=object),
#  array([808, <class 'list'>], dtype=object),
#  array([809, <class 'list'>], dtype=object),
#  array([810, <class 'list'>], dtype=object),
#  array([811, <class 'list'>], dtype=object),
#  array([812, <class 'list'>], dtype=object),
#  array([813, <class 'list'>], dtype=object),
#  array([814, <class 'list'>], dtype=object),
#  array([815, <class 'list'>], dtype=object),
#  array([816, <class 'list'>], dtype=object),
#  array([817, <class 'list'>], dtype=object),
#  array([818, <class 'list'>], dtype=object),
#  array([819, <class 'list'>], dtype=object),
#  array([820, <class 'list'>], dtype=object),
#  array([821, <class 'list'>], dtype=object),
#  array([822, <class 'list'>], dtype=object),
#  array([823, <class 'list'>], dtype=object),
#  array([824, <class 'list'>], dtype=object),
#  array([825, <class 'list'>], dtype=object),
#  array([826, <class 'list'>], dtype=object),
#  array([827, <class 'list'>], dtype=object),
#  array([828, <class 'list'>], dtype=object),
#  array([829, <class 'list'>], dtype=object),
#  array([830, <class 'list'>], dtype=object),
#  array([831, <class 'list'>], dtype=object),
#  array([832, <class 'list'>], dtype=object),
#  array([833, <class 'list'>], dtype=object),
#  array([834, <class 'list'>], dtype=object),
#  array([835, <class 'list'>], dtype=object),
#  array([836, <class 'list'>], dtype=object),
#  array([837, <class 'list'>], dtype=object),
#  array([838, <class 'list'>], dtype=object),
#  array([839, <class 'list'>], dtype=object),
#  array([840, <class 'list'>], dtype=object),
#  array([841, <class 'list'>], dtype=object),
#  array([842, <class 'list'>], dtype=object),
#  array([843, <class 'list'>], dtype=object),
#  array([844, <class 'list'>], dtype=object),
#  array([845, <class 'list'>], dtype=object),
#  array([846, <class 'list'>], dtype=object),
#  array([847, <class 'list'>], dtype=object),
#  array([848, <class 'list'>], dtype=object),
#  array([849, <class 'list'>], dtype=object),
#  array([850, <class 'list'>], dtype=object),
#  array([851, <class 'list'>], dtype=object),
#  array([852, <class 'list'>], dtype=object),
#  array([853, <class 'list'>], dtype=object),
#  array([854, <class 'list'>], dtype=object),
#  array([855, <class 'list'>], dtype=object),
#  array([856, <class 'list'>], dtype=object),
#  array([857, <class 'list'>], dtype=object),
#  array([858, <class 'list'>], dtype=object),
#  array([859, <class 'list'>], dtype=object),
#  array([860, <class 'list'>], dtype=object),
#  array([861, <class 'list'>], dtype=object),
#  array([862, <class 'list'>], dtype=object),
#  array([863, <class 'list'>], dtype=object),
#  array([864, <class 'list'>], dtype=object),
#  array([865, <class 'list'>], dtype=object),
#  array([866, <class 'list'>], dtype=object),
#  array([867, <class 'list'>], dtype=object),
#  array([868, <class 'list'>], dtype=object),
#  array([869, <class 'list'>], dtype=object),
#  array([870, <class 'list'>], dtype=object),
#  array([871, <class 'list'>], dtype=object),
#  array([872, <class 'list'>], dtype=object),
#  array([873, <class 'list'>], dtype=object),
#  array([874, <class 'list'>], dtype=object),
#  array([875, <class 'list'>], dtype=object),
#  array([876, <class 'list'>], dtype=object),
#  array([877, <class 'list'>], dtype=object),
#  array([878, <class 'list'>], dtype=object),
#  array([879, <class 'list'>], dtype=object),
#  array([880, <class 'list'>], dtype=object),
#  array([881, <class 'list'>], dtype=object),
#  array([882, <class 'list'>], dtype=object),
#  array([883, <class 'list'>], dtype=object),
#  array([884, <class 'list'>], dtype=object),
#  array([885, <class 'list'>], dtype=object),
#  array([886, <class 'list'>], dtype=object),
#  array([887, <class 'list'>], dtype=object),
#  array([888, <class 'list'>], dtype=object),
#  array([889, <class 'list'>], dtype=object),
#  array([890, <class 'list'>], dtype=object),
#  array([891, <class 'list'>], dtype=object),
#  array([892, <class 'list'>], dtype=object),
#  array([893, <class 'list'>], dtype=object),
#  array([894, <class 'list'>], dtype=object),
#  array([895, <class 'list'>], dtype=object),
#  array([896, <class 'list'>], dtype=object),
#  array([897, <class 'list'>], dtype=object),
#  array([898, <class 'list'>], dtype=object),
#  array([899, <class 'list'>], dtype=object),
#  array([900, <class 'list'>], dtype=object),
#  array([901, <class 'list'>], dtype=object),
#  array([902, <class 'list'>], dtype=object),
#  array([903, <class 'list'>], dtype=object),
#  array([904, <class 'list'>], dtype=object),
#  array([905, <class 'list'>], dtype=object),
#  array([906, <class 'list'>], dtype=object),
#  array([907, <class 'list'>], dtype=object),
#  array([908, <class 'list'>], dtype=object),
#  array([909, <class 'list'>], dtype=object),
#  array([910, <class 'list'>], dtype=object),
#  array([911, <class 'list'>], dtype=object),
#  array([912, <class 'list'>], dtype=object),
#  array([913, <class 'list'>], dtype=object),
#  array([914, <class 'list'>], dtype=object),
#  array([915, <class 'list'>], dtype=object),
#  array([916, <class 'list'>], dtype=object),
#  array([917, <class 'list'>], dtype=object),
#  array([918, <class 'list'>], dtype=object),
#  array([919, <class 'list'>], dtype=object),
#  array([920, <class 'list'>], dtype=object),
#  array([921, <class 'list'>], dtype=object),
#  array([922, <class 'list'>], dtype=object),
#  array([923, <class 'list'>], dtype=object),
#  array([924, <class 'list'>], dtype=object),
#  array([925, <class 'list'>], dtype=object),
#  array([926, <class 'list'>], dtype=object),
#  array([927, <class 'list'>], dtype=object),
#  array([928, <class 'list'>], dtype=object),
#  array([929, <class 'list'>], dtype=object),
#  array([930, <class 'list'>], dtype=object),
#  array([931, <class 'list'>], dtype=object),
#  array([932, <class 'list'>], dtype=object),
#  array([933, <class 'list'>], dtype=object),
#  array([934, <class 'list'>], dtype=object),
#  array([935, <class 'list'>], dtype=object),
#  array([936, <class 'list'>], dtype=object),
#  array([937, <class 'list'>], dtype=object),
#  array([938, <class 'list'>], dtype=object),
#  array([939, <class 'list'>], dtype=object),
#  array([940, <class 'list'>], dtype=object),
#  array([941, <class 'list'>], dtype=object),
#  array([942, <class 'list'>], dtype=object),
#  array([943, <class 'list'>], dtype=object),
#  array([944, <class 'list'>], dtype=object),
#  array([945, <class 'list'>], dtype=object),
#  array([946, <class 'list'>], dtype=object),
#  array([947, <class 'list'>], dtype=object),
#  array([948, <class 'list'>], dtype=object),
#  array([949, <class 'list'>], dtype=object),
#  array([950, <class 'list'>], dtype=object),
#  array([951, <class 'list'>], dtype=object),
#  array([952, <class 'list'>], dtype=object),
#  array([953, <class 'list'>], dtype=object),
#  array([954, <class 'list'>], dtype=object),
#  array([955, <class 'list'>], dtype=object),
#  array([956, <class 'list'>], dtype=object),
#  array([957, <class 'list'>], dtype=object),
#  array([958, <class 'list'>], dtype=object),
#  array([959, <class 'list'>], dtype=object),
#  array([960, <class 'list'>], dtype=object),
#  array([961, <class 'list'>], dtype=object),
#  array([962, <class 'list'>], dtype=object),
#  array([963, <class 'list'>], dtype=object),
#  array([964, <class 'list'>], dtype=object),
#  array([965, <class 'list'>], dtype=object),
#  array([966, <class 'list'>], dtype=object),
#  array([967, <class 'list'>], dtype=object),
#  array([968, <class 'list'>], dtype=object),
#  array([969, <class 'list'>], dtype=object),
#  array([970, <class 'list'>], dtype=object),
#  array([971, <class 'list'>], dtype=object),
#  array([972, <class 'list'>], dtype=object),
#  array([973, <class 'list'>], dtype=object),
#  array([974, <class 'list'>], dtype=object),
#  array([975, <class 'list'>], dtype=object),
#  array([976, <class 'list'>], dtype=object),
#  array([977, <class 'list'>], dtype=object),
#  array([978, <class 'list'>], dtype=object),
#  array([979, <class 'list'>], dtype=object),
#  array([980, <class 'list'>], dtype=object),
#  array([981, <class 'list'>], dtype=object),
#  array([982, <class 'list'>], dtype=object),
#  array([983, <class 'list'>], dtype=object),
#  array([984, <class 'list'>], dtype=object),
#  array([985, <class 'list'>], dtype=object),
#  array([986, <class 'list'>], dtype=object),
#  array([987, <class 'list'>], dtype=object),
#  array([988, <class 'list'>], dtype=object),
#  array([989, <class 'list'>], dtype=object),
#  array([990, <class 'list'>], dtype=object),
#  array([991, <class 'list'>], dtype=object),
#  array([992, <class 'list'>], dtype=object),
#  array([993, <class 'list'>], dtype=object),
#  array([994, <class 'list'>], dtype=object),
#  array([995, <class 'list'>], dtype=object),
#  array([996, <class 'list'>], dtype=object),
#  array([997, <class 'list'>], dtype=object),
#  array([998, <class 'list'>], dtype=object),
#  array([999, <class 'list'>], dtype=object),
#  ...]

# %%
temp
# Out:
# [array([ 0.        , 49.80320856, 51.57860963]),
#  array([ 1.        , 49.77077077, 50.95495495]),
#  array([ 2.        , 48.66830226, 50.24435721]),
#  array([ 3.        , 49.00996016, 48.70916335]),
#  array([ 4.       , 48.5106599, 48.4213198]),
#  array([ 5.        , 49.75834176, 50.48129424]),
#  array([ 6.        , 49.96028513, 49.02342159]),
#  array([ 7.        , 49.95643756, 49.45982575]),
#  array([ 8.        , 49.96908213, 48.10434783]),
#  array([ 9.        , 48.23036649, 50.66492147]),
#  array([10.        , 49.5050813 , 51.02337398]),
#  array([11.        , 50.77723735, 48.35603113]),
#  array([12.        , 48.39656912, 50.61049445]),
#  array([13.        , 51.25609756, 49.2449187 ]),
#  array([14.        , 51.07021063, 49.60882648]),
#  array([15.        , 48.3781344 , 47.60381143]),
#  array([16.        , 49.94305019, 49.05212355]),
#  array([17.        , 50.89020772, 49.27002967]),
#  array([18.        , 48.91173305, 50.87405813]),
#  array([19.        , 49.28367347, 49.46632653]),
#  array([20.        , 49.54545455, 49.23791103]),
#  array([21.        , 48.94482759, 48.45615764]),
#  array([22.        , 50.90319149, 48.25319149]),
#  array([23.        , 50.02908726, 49.26479438]),
#  array([24.        , 49.83043922, 50.54239019]),
#  array([25.        , 50.07631318, 49.20812686]),
#  array([26.        , 49.08994197, 50.4893617 ]),
#  array([27.        , 50.46963947, 47.00094877]),
#  array([28.        , 49.92892399, 49.49950642]),
#  array([29.        , 50.07328833, 48.79074253]),
#  array([30.        , 50.70741483, 49.90581162]),
#  array([31.        , 48.6567623 , 48.19364754]),
#  array([32.        , 48.80518135, 49.93056995]),
#  array([33.        , 49.31987891, 49.94651867]),
#  array([34.        , 49.04294479, 49.56646217]),
#  array([35.        , 49.66375121, 48.25947522]),
#  array([36.        , 48.43869732, 49.86302682]),
#  array([37.        , 50.63663075, 49.64446621]),
#  array([38.        , 50.30135558, 48.79144943]),
#  array([39.        , 49.54288597, 50.22300706]),
#  array([40.        , 51.95895896, 48.47547548]),
#  array([41.        , 49.61803445, 49.6656535 ]),
#  array([42.        , 49.555334  , 49.79262213]),
#  array([43.        , 49.95538312, 49.89621726]),
#  array([44.        , 49.02470356, 49.15513834]),
#  array([45.        , 49.39046653, 49.75760649]),
#  array([46.        , 49.53274682, 49.1769306 ]),
#  array([47.        , 49.86133603, 49.66295547]),
#  array([48.        , 47.48799232, 51.38904899]),
#  array([49.        , 48.84079602, 47.44975124]),
#  array([50.        , 48.38712972, 49.38815117]),
#  array([51.        , 48.70841487, 49.53522505]),
#  array([52.        , 48.51294821, 49.70418327]),
#  array([53.   , 50.297, 50.138]),
#  array([54.        , 49.07594937, 50.24634859]),
#  array([55.        , 48.9497992 , 48.79417671]),
#  array([56.        , 48.63796477, 49.38649706]),
#  array([57.        , 51.10079051, 49.16205534]),
#  array([58.        , 49.580348  , 50.55885363]),
#  array([59.        , 50.18860511, 49.6237721 ]),
#  array([60.        , 48.97556207, 49.41251222]),
#  array([61.        , 48.14688716, 47.9844358 ]),
#  array([62.        , 47.99901088, 49.22947577]),
#  array([63.        , 49.88198103, 48.75026344]),
#  array([64.        , 49.7754902 , 50.14901961]),
#  array([65.        , 46.46095238, 50.10857143]),
#  array([66.        , 48.77885548, 48.07662464]),
#  array([67.   , 48.639, 47.45 ]),
#  array([68.        , 49.24040404, 49.56161616]),
#  array([69.        , 49.2037962 , 50.49150849]),
#  array([70.        , 48.48118006, 49.22583927]),
#  array([71.        , 48.75      , 47.74795918]),
#  array([72.        , 48.08227228, 48.95004897]),
#  array([73.        , 48.20967742, 50.35987903]),
#  array([74.        , 48.15285996, 49.56508876]),
#  array([75.        , 50.95647969, 48.87717602]),
#  array([76.        , 49.59006211, 49.01138716]),
#  array([77.        , 49.22004132, 51.18181818]),
#  array([78.        , 49.08510638, 50.35203095]),
#  array([79.        , 49.8493014 , 50.15469062]),
#  array([80.        , 49.79519231, 48.30961538]),
#  array([81.        , 49.9140625 , 48.81445312]),
#  array([82.        , 50.66565962, 49.99194361]),
#  array([83.        , 50.06304559, 48.75751697]),
#  array([84.        , 47.53014553, 50.58523909]),
#  array([85.        , 48.70059289, 48.993083  ]),
#  array([86.        , 50.67374517, 49.3957529 ]),
#  array([87.        , 49.05644302, 50.15548456]),
#  array([88.        , 50.78778779, 48.48348348]),
#  array([89.        , 49.30814524, 50.72227674]),
#  array([90.        , 47.06750241, 49.76374156]),
#  array([91.        , 49.12011439, 49.97330791]),
#  array([92.        , 50.24899194, 47.9828629 ]),
#  array([93.        , 46.80058083, 48.59438529]),
#  array([94.        , 49.50442478, 50.35988201]),
#  array([95.        , 46.82726327, 49.04786681]),
#  array([96.        , 48.29636899, 51.30716389]),
#  array([97.        , 49.6879845 , 52.23062016]),
#  array([98.        , 47.91286307, 49.41390041]),
#  array([99.        , 48.78144989, 49.62686567]),
#  array([100.        ,  48.20087816,  49.74094402]),
#  array([101.        ,  48.63076923,  50.46871795]),
#  array([102.        ,  48.29192547,  50.20186335]),
#  array([103.        ,  49.76714976,  49.45990338]),
#  array([104.        ,  50.08198381,  48.89068826]),
#  array([105.        ,  50.46343874,  47.4486166 ]),
#  array([106.        ,  49.45033113,  49.28287606]),
#  array([107.        ,  49.58765916,  49.86777669]),
#  array([108.        ,  49.27316602,  48.68050193]),
#  array([109.        ,  48.01074219,  49.47460938]),
#  array([110.        ,  49.28715875,  50.45500506]),
#  array([111.        ,  48.82996812,  49.25717322]),
#  array([112.        ,  48.14187192,  49.60689655]),
#  array([113.        ,  49.12979351,  50.91150442]),
#  array([114.        ,  50.27216495,  48.91340206]),
#  array([115.        ,  49.075     ,  49.43557692]),
#  array([116.        ,  51.16618076,  49.797862  ]),
#  array([117.       ,  48.6743295,  50.1302682]),
#  array([118.        ,  49.26545842,  49.27185501]),
#  array([119.        ,  48.52970297,  50.3009901 ]),
#  array([120.        ,  50.46122449,  48.97142857]),
#  array([121.        ,  49.84801549,  49.31848984]),
#  array([122.        ,  48.68214654,  48.85345717]),
#  array([123.        ,  49.36016512,  49.59442724]),
#  array([124.        ,  49.20475698,  46.87176836]),
#  array([125.        ,  47.66633367,  49.75924076]),
#  array([126.        ,  50.96415094,  49.29433962]),
#  array([127.        ,  48.97686117,  50.09657948]),
#  array([128.        ,  49.93936382,  50.42942346]),
#  array([129.        ,  48.64663951,  49.71588595]),
#  array([130.        ,  48.7831094 ,  50.59117083]),
#  array([131.        ,  49.88003839,  48.29846449]),
#  array([132.        ,  49.24404194,  51.21639657]),
#  array([133.        ,  51.10871795,  50.42358974]),
#  array([134.        ,  49.69275362,  48.63574879]),
#  array([135.        ,  50.88667992,  48.25944334]),
#  array([136.        ,  49.23357664,  49.90198123]),
#  array([137.   ,  50.701,  50.126]),
#  array([138.        ,  49.49201597,  50.25449102]),
#  array([139.        ,  49.35594887,  50.28908555]),
#  array([140.        ,  49.82515337,  49.15746421]),
#  array([141.        ,  49.50401606,  48.40160643]),
#  array([142.        ,  49.60334646,  49.27559055]),
#  array([143.        ,  47.79383634,  49.88097768]),
#  array([144.        ,  49.6097561 ,  49.88719512]),
#  array([145.        ,  48.6693712 ,  50.09736308]),
#  array([146.        ,  46.29022403,  50.22810591]),
#  array([147.        ,  49.0285423 ,  50.68807339]),
#  array([148.        ,  49.34773663,  48.41460905]),
#  array([149.        ,  51.0627451 ,  50.18823529]),
#  array([150.        ,  48.85801839,  49.23799796]),
#  array([151.        ,  49.30637488,  48.97621313]),
#  array([152.        ,  49.88235294,  49.82765738]),
#  array([153.        ,  49.44820717,  50.01792829]),
#  array([154.        ,  49.94802495,  50.26923077]),
#  array([155.        ,  48.2374031 ,  51.09496124]),
#  array([156.        ,  50.06983511,  49.54025218]),
#  array([157.        ,  49.47046843,  48.93991853]),
#  array([158.        ,  48.84954865,  50.09528586]),
#  array([159.   ,  48.088,  50.47 ]),
#  array([160.        ,  50.62062615,  48.19429098]),
#  array([161.        ,  49.48841893,  48.86404834]),
#  array([162.        ,  49.20972355,  50.4442326 ]),
#  array([163.        ,  50.39292731,  46.86738703]),
#  array([164.        ,  49.95635674,  48.86622391]),
#  array([165.        ,  48.94618395,  50.82681018]),
#  array([166.        ,  51.11969112,  48.18532819]),
#  array([167.        ,  48.50291829,  50.39688716]),
#  array([168.        ,  51.3132154 ,  50.01352758]),
#  array([169.        ,  50.67835671,  49.76452906]),
#  array([170.        ,  51.02527806,  50.47118301]),
#  array([171.        ,  50.2246604 ,  48.35423197]),
#  array([172.        ,  50.23333333,  48.59677419]),
#  array([173.        ,  50.03571429,  50.31949807]),
#  array([174.        ,  50.16762452,  47.92816092]),
#  array([175.        ,  49.42366412,  49.68416031]),
#  array([176.        ,  51.09543147,  48.00913706]),
#  array([177.        ,  48.51120163,  51.19450102]),
#  array([178.        ,  48.68113017,  48.42482341]),
#  array([179.        ,  48.4033092 ,  50.12306101]),
#  array([180.        ,  48.61003071,  50.76356192]),
#  array([181.        ,  48.24451098,  50.34630739]),
#  array([182.        ,  49.29365079,  50.52380952]),
#  array([183.        ,  50.2686722 ,  49.15456432]),
#  array([184.        ,  49.36967809,  49.4569055 ]),
#  array([185.   ,  48.232,  49.322]),
#  array([186.        ,  50.1714876 ,  49.14256198]),
#  array([187.        ,  50.33766234,  48.95104895]),
#  array([188.        ,  49.64250248,  49.49056604]),
#  array([189.        ,  49.65860735,  49.3868472 ]),
#  array([190.        ,  49.11648569,  49.77788746]),
#  array([191.        ,  47.82190379,  49.3357216 ]),
#  array([192.        ,  50.2247191 ,  49.36423221]),
#  array([193.        ,  48.69247312,  49.45591398]),
#  array([194.        ,  49.62589195,  49.509684  ]),
#  array([195.        ,  50.996875  ,  48.72395833]),
#  array([196.        ,  49.01388889,  48.27281746]),
#  array([197.        ,  48.98134715,  48.89119171]),
#  array([198.        ,  48.95891784,  49.25751503]),
#  array([199.        ,  49.81045082,  48.0317623 ]),
#  array([200.        ,  49.12680412,  50.80618557]),
#  array([201.        ,  49.71940928,  49.93459916]),
#  array([202.        ,  50.23365385,  50.07307692]),
#  array([203.        ,  49.21743205,  49.30927835]),
#  array([204.        ,  50.36810431,  50.87462387]),
#  array([205.        ,  49.79479479,  48.38438438]),
#  array([206.        ,  50.45666991,  50.41480039]),
#  array([207.        ,  49.68073593,  48.83766234]),
#  array([208.        ,  48.04771372,  49.78926441]),
#  array([209.        ,  49.3003003 ,  50.52052052]),
#  array([210.        ,  49.21188119,  49.51980198]),
#  array([211.        ,  48.63812155,  49.16298343]),
#  array([212.        ,  50.30905512,  50.21259843]),
#  array([213.        ,  49.78748759,  48.84707051]),
#  array([214.        ,  48.15615907,  49.37730359]),
#  array([215.        ,  49.23198421,  49.84698914]),
#  array([216.        ,  50.72371134,  48.09072165]),
#  array([217.        ,  49.38185444,  48.        ]),
#  array([218.        ,  50.2271028 ,  50.35233645]),
#  array([219.        ,  49.29979466,  48.60061602]),
#  array([220.        ,  49.61919192,  47.38080808]),
#  array([221.        ,  47.99109792,  47.98911968]),
#  array([222.        ,  50.47808359,  50.30071356]),
#  array([223.        ,  48.5995872 ,  49.60887513]),
#  array([224.        ,  49.91826438,  48.55499495]),
#  array([225.        ,  49.17806841,  49.74245473]),
#  array([226.        ,  48.94129763,  49.23480947]),
#  array([227.        ,  49.71540726,  49.27870461]),
#  array([228.        ,  48.70559846,  50.1003861 ]),
#  array([229.        ,  46.94152047,  49.82748538]),
#  array([230.        ,  49.16112266,  48.56237006]),
#  array([231.        ,  48.0441324 ,  48.27683049]),
#  array([232.       ,  50.6086529,  48.9252704]),
#  array([233.        ,  49.74953096,  49.41557223]),
#  array([234.        ,  49.52610837,  50.08374384]),
#  array([235.        ,  48.82217782,  51.00699301]),
#  array([236.        ,  49.96704428,  49.57466529]),
#  array([237.        ,  49.58592965,  51.06633166]),
#  array([238.        ,  49.08375378,  48.44096872]),
#  array([239.        ,  49.34329797,  49.06557377]),
#  array([240.        ,  48.40345528,  48.80691057]),
#  array([241.        ,  50.09297297,  47.68756757]),
#  array([242.        ,  48.68149646,  48.85844287]),
#  array([243.        ,  50.45795339,  49.37993921]),
#  array([244.        ,  49.08402585,  49.2179132 ]),
#  array([245.        ,  49.20686176,  48.21594349]),
#  array([246.        ,  48.77684211,  49.24947368]),
#  array([247.        ,  49.80294118,  50.06372549]),
#  array([248.        ,  49.38981391,  49.78354554]),
#  array([249.        ,  50.81237323,  48.60141988]),
#  array([250.        ,  49.14416244,  50.08121827]),
#  array([251.   ,  48.404,  49.492]),
#  array([252.        ,  49.00389105,  48.81225681]),
#  array([253.        ,  48.23030303,  49.40707071]),
#  array([254.        ,  49.36308316,  50.5030426 ]),
#  array([255.        ,  49.23296033,  49.6276704 ]),
#  array([256.        ,  50.24615385,  50.16307692]),
#  array([257.        ,  48.88341709,  49.03819095]),
#  array([258.        ,  49.36561265,  50.33300395]),
#  array([259.        ,  49.69207623,  49.58274824]),
#  array([260.        ,  49.82092555,  46.91851107]),
#  array([261.        ,  48.38753651,  49.00778968]),
#  array([262.        ,  49.01671891,  48.56426332]),
#  array([263.        ,  48.46673597,  50.18503119]),
#  array([264.        ,  49.2224554 ,  50.28856243]),
#  array([265.        ,  48.22335025,  49.90152284]),
#  array([266.        ,  50.57512438,  49.68855721]),
#  array([267.        ,  49.23899371,  49.17085954]),
#  array([268.        ,  49.74209012,  49.29626079]),
#  array([269.        ,  48.28414756,  48.33499501]),
#  array([270.        ,  50.2183908 ,  49.75287356]),
#  array([271.        ,  49.97729516,  48.4076999 ]),
#  array([272.        ,  48.5813253 ,  48.55923695]),
#  array([273.        ,  49.37809917,  50.04752066]),
#  array([274.        ,  49.52199413,  50.06256109]),
#  array([275.        ,  48.87946885,  48.72931563]),
#  array([276.        ,  50.19469929,  50.87359837]),
#  array([277.        ,  48.80413386,  50.27165354]),
#  array([278.        ,  50.64605544,  48.82729211]),
#  array([279.        ,  47.12230216,  49.92086331]),
#  array([280.        ,  49.0776699 ,  50.98932039]),
#  array([281.        ,  48.77272727,  49.04545455]),
#  array([282.        ,  49.38538539,  49.56156156]),
#  array([283.        ,  49.26065411,  50.55996036]),
#  array([284.        ,  49.03816047,  48.81702544]),
#  array([285.        ,  49.13614104,  50.01665034]),
#  array([286.        ,  47.96331237,  49.84696017]),
#  array([287.        ,  49.38681102,  48.28740157]),
#  array([288.        ,  49.81280788,  48.67192118]),
#  array([289.        ,  48.57334612,  50.49472675]),
#  array([290.        ,  49.71515768,  47.05900305]),
#  array([291.        ,  48.7544596 ,  50.07869885]),
#  array([292.        ,  48.30271399,  50.42588727]),
#  array([293.        ,  49.58892128,  50.04373178]),
#  array([294.        ,  50.02390438,  50.10258964]),
#  array([295.        ,  48.85032741,  49.48924228]),
#  array([296.        ,  51.54028436,  48.01990521]),
#  array([297.        ,  50.76403425,  48.9019981 ]),
#  array([298.        ,  49.54973262,  50.66417112]),
#  array([299.        ,  48.58429119,  48.62452107]),
#  array([300.        ,  49.08474576,  49.96111665]),
#  array([301.        ,  49.14721346,  48.37644585]),
#  array([302.        ,  49.4673913 ,  48.86561265]),
#  array([303.        ,  50.06072874,  50.15283401]),
#  array([304.        ,  49.1692607 ,  49.24708171]),
#  array([305.        ,  49.42014242,  48.62563581]),
#  array([306.        ,  49.26036644,  49.84378014]),
#  array([307.        ,  50.33589251,  48.58733205]),
#  array([308.        ,  51.70868644,  49.40148305]),
#  array([309.        ,  50.35671343,  48.28957916]),
#  array([310.        ,  50.44554455,  50.78514851]),
#  array([311.        ,  49.65198238,  48.97136564]),
#  array([312.        ,  48.2104712 ,  48.54240838]),
#  array([313.        ,  48.66700611,  50.4898167 ]),
#  array([314.        ,  48.52410256,  49.94666667]),
#  array([315.        ,  49.64152791,  50.0675808 ]),
#  array([316.        ,  48.56822811,  47.9389002 ]),
#  array([317.        ,  49.46098563,  50.69712526]),
#  array([318.        ,  49.96871945,  50.29521017]),
#  array([319.        ,  49.89252815,  49.88536336]),
#  array([320.        ,  50.01239669,  50.42045455]),
#  array([321.        ,  47.71330049,  49.08965517]),
#  array([322.        ,  48.55041152,  50.81378601]),
#  array([323.        ,  48.61072493,  49.63753724]),
#  array([324.        ,  47.9345887 ,  49.15956392]),
#  array([325.        ,  50.33535968,  49.03242148]),
#  array([326.        ,  48.314258  ,  48.72550921]),
#  array([327.        ,  48.92401216,  50.02836879]),
#  array([328.   ,  49.991,  48.536]),
#  array([329.        ,  51.54154154,  51.19319319]),
#  array([330.        ,  51.35987261,  49.79299363]),
#  array([331.        ,  50.20512821,  48.77810651]),
#  array([332.        ,  50.09950249,  49.32935323]),
#  array([333.        ,  50.09960938,  48.3046875 ]),
#  array([334.        ,  49.20412371,  49.84123711]),
#  array([335.        ,  48.8964497 ,  48.09861933]),
#  array([336.        ,  49.83983984,  50.36236236]),
#  array([337.        ,  50.17823834,  49.53678756]),
#  array([338.        ,  48.12981744,  47.96855984]),
#  array([339.        ,  47.29162358,  50.4705274 ]),
#  array([340.        ,  49.52952953,  49.84884885]),
#  array([341.        ,  47.41456016,  48.75733064]),
#  array([342.        ,  51.00987167,  48.47384008]),
#  array([343.        ,  49.00380952,  49.01619048]),
#  array([344.        ,  49.69753086,  51.49074074]),
#  array([345.        ,  49.61375126,  51.10920121]),
#  array([346.        ,  49.8832998 ,  49.74748491]),
#  array([347.        ,  49.59193246,  51.13320826]),
#  array([348.        ,  50.27579737,  47.61913696]),
#  array([349.        ,  50.0107949 ,  50.28361138]),
#  array([350.        ,  52.14818653,  49.73367876]),
#  array([351.        ,  50.61805556,  50.11805556]),
#  array([352.        ,  48.96756757,  49.88540541]),
#  array([353.        ,  49.09402547,  48.86385896]),
#  array([354.        ,  47.63580247,  50.06378601]),
#  array([355.        ,  50.51305221,  50.1124498 ]),
#  array([356.        ,  49.90909091,  49.16666667]),
#  array([357.        ,  50.81889764,  48.33562992]),
#  array([358.        ,  49.94117647,  49.67807487]),
#  array([359.        ,  49.46979167,  49.509375  ]),
#  array([360.        ,  48.04906054,  51.54906054]),
#  array([361.        ,  49.37364798,  50.12586037]),
#  array([362.        ,  50.05163853,  48.71002979]),
#  array([363.        ,  50.18518519,  49.22709552]),
#  array([364.        ,  49.56442308,  49.3625    ]),
#  array([365.        ,  50.45038911,  49.16828794]),
#  array([366.        ,  49.95660559,  51.43201543]),
#  array([367.        ,  49.40665994,  48.51059536]),
#  array([368.        ,  49.23827392,  48.9727955 ]),
#  array([369.        ,  49.21521522,  48.56756757]),
#  array([370.        ,  49.25655977,  49.01943635]),
#  array([371.        ,  48.11156602,  49.75332651]),
#  array([372.        ,  49.44254032,  49.41330645]),
#  array([373.        ,  49.15469613,  49.47403315]),
#  array([374.        ,  49.39244186,  48.48449612]),
#  array([375.        ,  49.77721774,  50.125     ]),
#  array([376.        ,  48.78544061,  49.11206897]),
#  array([377.        ,  49.24296142,  48.68196038]),
#  array([378.        ,  50.02647658,  49.52138493]),
#  array([379.        ,  48.23084677,  49.32358871]),
#  array([380.        ,  49.31541582,  49.92089249]),
#  array([381.        ,  50.34863281,  49.90820312]),
#  array([382.        ,  49.79888268,  49.11266294]),
#  array([383.        ,  50.11860941,  50.4591002 ]),
#  array([384.        ,  48.22846079,  49.22071636]),
#  array([385.        ,  49.00315126,  50.39810924]),
#  array([386.        ,  51.3079922 ,  51.55653021]),
#  array([387.        ,  50.03948773,  49.47812166]),
#  array([388.        ,  49.0420082 ,  49.35553279]),
#  array([389.        ,  48.37884615,  48.20096154]),
#  array([390.        ,  48.9534413 ,  49.90991903]),
#  array([391.        ,  48.50333651,  48.80552908]),
#  array([392.        ,  48.65965966,  50.66166166]),
#  array([393.        ,  49.62564633,  48.73940021]),
#  array([394.        ,  50.11146497,  48.98301486]),
#  array([395.        ,  49.68577075,  50.25790514]),
#  array([396.        ,  48.18577075,  49.66304348]),
#  array([397.        ,  48.96374622,  49.81671702]),
#  array([398.        ,  50.73716632,  48.6026694 ]),
#  array([399.        ,  49.88965517,  48.64729064]),
#  array([400.        ,  49.51195219,  50.8376494 ]),
#  array([401.        ,  49.7182426 ,  49.63705826]),
#  array([402.        ,  50.49117647,  48.7872549 ]),
#  array([403.        ,  50.35387885,  48.98405951]),
#  array([404.        ,  49.80524723,  48.82643794]),
#  array([405.        ,  49.1459144 ,  49.53404669]),
#  array([406.        ,  49.32413793,  51.29950739]),
#  array([407.        ,  49.87831207,  47.82630029]),
#  array([408.        ,  49.11661808,  48.80855199]),
#  array([409.        ,  48.73734479,  50.28844317]),
#  array([410.        ,  48.45872518,  49.        ]),
#  array([411.        ,  48.71428571,  48.86100386]),
#  array([412.        ,  51.05600815,  50.09979633]),
#  array([413.        ,  49.37202073,  48.95751295]),
#  array([414.        ,  50.7402863 ,  49.57055215]),
#  array([415.        ,  48.45170732,  50.59219512]),
#  array([416.        ,  50.59778226,  48.45060484]),
#  array([417.        ,  48.10192308,  49.28942308]),
#  array([418.        ,  49.6003937 ,  50.31889764]),
#  array([419.        ,  50.15053763,  49.88709677]),
#  array([420.        ,  48.42755102,  48.33265306]),
#  array([421.        ,  48.95009785,  49.43248532]),
#  array([422.        ,  48.59358289,  50.65347594]),
#  array([423.        ,  48.51081359,  49.89495366]),
#  array([424.        ,  49.92984293,  49.14136126]),
#  array([425.        ,  49.23919308,  50.26224784]),
#  array([426.        ,  49.9184322 ,  50.35381356]),
#  array([427.        ,  50.56827309,  49.89156627]),
#  array([428.        ,  49.14503043,  48.58924949]),
#  array([429.        ,  48.86174636,  49.16839917]),
#  array([430.        ,  49.36934156,  48.97942387]),
#  array([431.        ,  48.95863495,  51.07652534]),
#  array([432.        ,  50.26930693,  49.26237624]),
#  array([433.        ,  49.04646465,  49.62525253]),
#  array([434.        ,  47.50809717,  48.39979757]),
#  array([435.        ,  50.5752303 ,  50.45445241]),
#  array([436.        ,  49.04405738,  50.0727459 ]),
#  array([437.        ,  48.66597294,  49.09781478]),
#  array([438.        ,  48.33736153,  50.65861027]),
#  array([439.        ,  49.94962487,  49.55519829]),
#  array([440.        ,  48.62475634,  49.73781676]),
#  array([441.        ,  48.31268437,  50.72566372]),
#  array([442.        ,  48.6134715 ,  48.94196891]),
#  array([443.        ,  49.26037344,  49.8060166 ]),
#  array([444.        ,  49.14489796,  52.58673469]),
#  array([445.        ,  49.35960591,  49.53103448]),
#  array([446.        ,  49.94864048,  49.63343404]),
#  array([447.        ,  48.38725024,  48.8981922 ]),
#  array([448.        ,  50.96577947,  51.09410646]),
#  array([449.        ,  49.37308869,  49.81753313]),
#  array([450.        ,  48.89932236,  50.43272023]),
#  array([451.        ,  49.93737166,  49.02053388]),
#  array([452.        ,  47.3954918 ,  49.09221311]),
#  array([453.        ,  48.27229147,  49.13902205]),
#  array([454.        ,  48.95205479,  47.56947162]),
#  array([455.        ,  48.8820059 ,  49.34414946]),
#  array([456.        ,  49.09566075,  49.11439842]),
#  array([457.        ,  49.6359127 ,  50.35813492]),
#  array([458.        ,  49.07128514,  48.91465863]),
#  array([459.        ,  49.24184261,  49.51055662]),
#  array([460.        ,  48.40446169,  48.7129001 ]),
#  array([461.        ,  50.28978389,  50.51473477]),
#  array([462.        ,  49.1809816 ,  50.26584867]),
#  array([463.        ,  49.82436548,  49.24873096]),
#  array([464.        ,  50.19037657,  50.61297071]),
#  array([465.        ,  48.79396985,  48.78090452]),
#  array([466.        ,  50.02258727,  48.44147844]),
#  array([467.        ,  51.18318318,  49.84484484]),
#  array([468.        ,  49.27087576,  47.83808554]),
#  array([469.        ,  50.52684904,  50.31813576]),
#  array([470.        ,  49.34545455,  48.25727273]),
#  array([471.        ,  48.35023923,  49.8937799 ]),
#  array([472.        ,  49.10950413,  49.81404959]),
#  array([473.        ,  49.96016343,  48.95914198]),
#  array([474.        ,  49.35369458,  49.5320197 ]),
#  array([475.        ,  47.90718563,  49.82734531]),
#  array([476.        ,  48.72309198,  50.3072407 ]),
#  array([477.        ,  48.6858006 ,  50.19033233]),
#  array([478.        ,  49.28331584,  49.90346275]),
#  array([479.        ,  47.97681452,  51.55141129]),
#  array([480.        ,  48.50469043,  49.94090056]),
#  array([481.        ,  48.78503688,  49.26554268]),
#  array([482.        ,  48.68568665,  49.35299807]),
#  array([483.        ,  48.89380531,  49.80235988]),
#  array([484.        ,  49.49246231,  51.2160804 ]),
#  array([485.        ,  50.18389662,  49.23260437]),
#  array([486.        ,  51.81114551,  50.11764706]),
#  array([487.        ,  48.98080614,  50.68426104]),
#  array([488.        ,  48.72431333,  49.90742625]),
#  array([489.        ,  48.51814516,  49.48387097]),
#  array([490.        ,  47.89720559,  49.98502994]),
#  array([491.        ,  50.18293839,  49.08720379]),
#  array([492.       ,  50.6409002,  51.2074364]),
#  array([493.        ,  49.75732218,  49.26150628]),
#  array([494.        ,  49.69064748,  49.43473792]),
#  array([495.        ,  48.6752988 ,  49.59063745]),
#  array([496.        ,  51.22865854,  50.65955285]),
#  array([497.        ,  50.51873199,  49.53410183]),
#  array([498.        ,  48.84808853,  48.94768612]),
#  array([499.        ,  48.93346774,  50.04637097]),
#  array([500.        ,  50.86812046,  49.69574247]),
#  array([501.        ,  50.4870317 ,  49.95869356]),
#  array([502.        ,  50.31578947,  49.7611336 ]),
#  array([503.        ,  46.63983488,  52.21465428]),
#  array([504.        ,  50.        ,  49.84917355]),
#  array([505.        ,  48.83269598,  48.63862333]),
#  array([506.        ,  50.94297352,  48.36456212]),
#  array([507.        ,  49.71862745,  50.10686275]),
#  array([508.        ,  48.22310757,  49.93525896]),
#  array([509.        ,  49.01903808,  49.05210421]),
#  array([510.        ,  49.24435721,  49.57409225]),
#  array([511.        ,  49.14330875,  50.19072708]),
#  array([512.        ,  48.07263682,  49.33134328]),
#  array([513.        ,  50.29115128,  50.14081827]),
#  array([514.        ,  49.54818653,  48.2134715 ]),
#  array([515.        ,  49.92003854,  49.96339114]),
#  array([516.        ,  51.0905307 ,  49.91467222]),
#  array([517.      ,  49.271875,  48.4375  ]),
#  array([518.        ,  48.17874876,  49.41410129]),
#  array([519.        ,  49.93055556,  49.32837302]),
#  array([520.        ,  50.60503388,  49.32817038]),
#  array([521.        ,  51.20779221,  48.997003  ]),
#  array([522.        ,  49.30694143,  49.78091106]),
#  array([523.        ,  48.88499025,  48.39181287]),
#  array([524.        ,  49.14715026,  48.18341969]),
#  array([525.        ,  49.7456765 ,  49.97863683]),
#  array([526.        ,  48.33501514,  48.83148335]),
#  array([527.        ,  49.13500482,  50.42044359]),
#  array([528.        ,  49.29944547,  49.70055453]),
#  array([529.        ,  49.93987976,  48.89779559]),
#  array([530.        ,  49.62683643,  47.82761998]),
#  array([531.        ,  49.88229376,  50.22032193]),
#  array([532.        ,  49.27505112,  48.50204499]),
#  array([533.        ,  48.57569721,  49.38944223]),
#  array([534.        ,  48.6888454 ,  50.67318982]),
#  array([535.        ,  49.50549451,  50.76123876]),
#  array([536.        ,  49.69038076,  50.63326653]),
#  array([537.        ,  50.61464968,  50.71549894]),
#  array([538.        ,  49.74735831,  49.5456292 ]),
#  array([539.        ,  50.23260437,  50.16500994]),
#  array([540.        ,  50.90397045,  50.17728532]),
#  array([541.        ,  48.24502618,  50.79895288]),
#  array([542.        ,  49.96407767,  49.07864078]),
#  array([543.        ,  48.43895055,  50.63572149]),
#  array([544.        ,  50.56596173,  49.55186304]),
#  array([545.        ,  49.51348548,  49.55497925]),
#  array([546.        ,  49.14360587,  50.03354298]),
#  array([547.        ,  48.98272553,  47.3378119 ]),
#  array([548.        ,  49.37654909,  49.16110582]),
#  array([549.        ,  50.24671385,  47.77957533]),
#  array([550.        ,  49.73306773,  50.89043825]),
#  array([551.        ,  49.44965105,  49.20438684]),
#  array([552.        ,  48.85743381,  48.38187373]),
#  array([553.        ,  51.01756098,  48.86926829]),
#  array([554.        ,  49.42957746,  50.92152918]),
#  array([555.        ,  48.19875776,  49.05797101]),
#  array([556.        ,  48.72502379,  50.22359657]),
#  array([557.        ,  50.32401157,  49.61041466]),
#  array([558.        ,  49.52221125,  49.011846  ]),
#  array([559.        ,  50.02453988,  50.2597137 ]),
#  array([560.        ,  49.78185328,  49.30405405]),
#  array([561.        ,  50.18924111,  49.75792507]),
#  array([562.        ,  48.91846758,  49.45579568]),
#  array([563.        ,  49.64055794,  48.49356223]),
#  array([564.        ,  50.91170635,  49.4156746 ]),
#  array([565.        ,  48.72284264,  49.23451777]),
#  array([566.        ,  50.70949185,  49.37583893]),
#  array([567.        ,  48.35412668,  50.47216891]),
#  array([568.        ,  47.87587588,  49.83983984]),
#  array([569.        ,  49.53405726,  50.64067127]),
#  array([570.        ,  49.58865248,  50.37082067]),
#  array([571.        ,  47.91601562,  49.14550781]),
#  array([572.        ,  49.37225549,  48.19061876]),
#  array([573.        ,  48.94472876,  48.97441146]),
#  array([574.        ,  50.62486828,  48.73445732]),
#  array([575.        ,  48.98352214,  49.47476828]),
#  array([576.        ,  49.74787234,  48.49787234]),
#  array([577.        ,  49.39378238,  49.41968912]),
#  array([578.        ,  49.33677686,  49.69834711]),
#  array([579.        ,  50.54509018,  49.3256513 ]),
#  array([580.        ,  49.02683897,  48.57355865]),
#  array([581.        ,  48.96458333,  49.896875  ]),
#  array([582.        ,  50.53564155,  50.82484725]),
#  array([583.        ,  50.46230159,  49.00396825]),
#  array([584.        ,  50.16634799,  49.16539197]),
#  array([585.        ,  47.95626243,  50.00994036]),
#  array([586.        ,  50.60591603,  49.91221374]),
#  array([587.        ,  50.8624498 ,  50.10843373]),
#  array([588.        ,  51.15794769,  50.01408451]),
#  array([589.        ,  50.07700422,  50.12552743]),
#  array([590.        ,  49.15384615,  51.09116809]),
#  array([591.        ,  50.82066869,  49.95542047]),
#  array([592.        ,  48.67141404,  50.3224822 ]),
#  array([593.        ,  47.52803262,  50.66258919]),
#  array([594.        ,  50.67444219,  49.78397566]),
#  array([595.        ,  50.57497517,  48.47269116]),
#  array([596.        ,  50.5648415 ,  49.62536023]),
#  array([597.        ,  49.25866917,  49.32146204]),
#  array([598.        ,  49.36080402,  51.59698492]),
#  array([599.        ,  49.45861733,  49.51022395]),
#  array([600.        ,  48.9825641 ,  49.11076923]),
#  array([601.        ,  50.84707051,  49.88182721]),
#  array([602.        ,  50.37986042,  48.60717846]),
#  array([603.        ,  49.16177958,  49.63397371]),
#  array([604.       ,  48.9852071,  50.7495069]),
#  array([605.        ,  49.49528302,  49.01320755]),
#  array([606.        ,  50.5627572 ,  49.27983539]),
#  array([607.       ,  50.5171737,  49.7016683]),
#  array([608.        ,  48.61267606,  50.2806841 ]),
#  array([609.        ,  49.6225641 ,  49.16102564]),
#  array([610.        ,  49.18683446,  49.44917715]),
#  array([611.        ,  51.43026706,  49.15825915]),
#  array([612.        ,  49.72079208,  50.18613861]),
#  array([613.        ,  50.13077679,  49.98525074]),
#  array([614.        ,  49.46858908,  49.60453141]),
#  array([615.        ,  49.35931174,  50.38967611]),
#  array([616.        ,  50.93521421,  49.88087774]),
#  array([617.        ,  50.0497561 ,  51.13073171]),
#  array([618.        ,  49.05811623,  48.58717435]),
#  array([619.        ,  50.36170213,  50.38974855]),
#  array([620.        ,  48.90287413,  49.32210109]),
#  array([621.        ,  48.55920398,  48.84975124]),
#  array([622.        ,  47.61808511,  49.05957447]),
#  array([623.        ,  50.81456311,  49.24757282]),
#  array([624.        ,  49.54435484,  49.38709677]),
#  array([625.        ,  49.76269621,  48.81532779]),
#  array([626.        ,  50.08677249,  50.86455026]),
#  array([627.        ,  49.47227723,  50.5009901 ]),
#  array([628.        ,  49.76428571,  50.94693878]),
#  array([629.        ,  48.85521236,  50.89478764]),
#  array([630.        ,  51.13948919,  49.19744597]),
#  array([631.        ,  49.79101562,  49.73046875]),
#  array([632.        ,  49.36847492,  50.0419652 ]),
#  array([633.        ,  49.88180884,  50.09660843]),
#  array([634.        ,  49.87371663,  48.97433265]),
#  array([635.        ,  49.22580645,  48.50806452]),
#  array([636.        ,  49.36363636,  48.07820137]),
#  array([637.        ,  50.31780538,  49.70393375]),
#  array([638.        ,  50.47628658,  49.8345106 ]),
#  array([639.        ,  52.55010438,  48.63569937]),
#  array([640.        ,  49.85888993,  49.47412982]),
#  array([641.        ,  49.45348837,  49.79281184]),
#  array([642.        ,  50.64206269,  48.74721941]),
#  array([643.        ,  50.43375859,  50.25809617]),
#  array([644.        ,  48.44111776,  51.58183633]),
#  array([645.        ,  49.40963855,  49.17771084]),
#  array([646.        ,  51.01666667,  49.70588235]),
#  array([647.        ,  49.8942774 ,  49.32783705]),
#  array([648.        ,  49.58921569,  49.79901961]),
#  array([649.        ,  48.04141414,  51.51212121]),
#  array([650.        ,  49.29492188,  48.99023438]),
#  array([651.       ,  49.0451423,  50.3326791]),
#  array([652.        ,  50.55816327,  50.84081633]),
#  array([653.        ,  50.37678402,  48.47002854]),
#  array([654.        ,  49.07490272,  51.19844358]),
#  array([655.        ,  48.54545455,  51.0040404 ]),
#  array([656.        ,  50.63307241,  49.97651663]),
#  array([657.        ,  49.49805825,  49.67864078]),
#  array([658.        ,  49.34384236,  49.80591133]),
#  array([659.        ,  49.56051587,  50.03075397]),
#  array([660.        ,  47.45383104,  49.97347741]),
#  array([661.        ,  51.07676349,  50.28215768]),
#  array([662.        ,  48.94258873,  49.86430063]),
#  array([663.        ,  48.63448276,  50.14975369]),
#  array([664.        ,  49.48247423,  48.7556701 ]),
#  array([665.        ,  50.1641791 ,  47.46169154]),
#  array([666.        ,  49.40233236,  51.3654033 ]),
#  array([667.        ,  48.49895616,  50.52505219]),
#  array([668.        ,  50.2848723 ,  48.91650295]),
#  array([669.        ,  49.21613237,  49.07549121]),
#  array([670.        ,  50.78121775,  50.93498452]),
#  array([671.        ,  48.70600632,  50.24762908]),
#  array([672.        ,  49.66084275,  50.22302158]),
#  array([673.        ,  47.74379345,  49.72889772]),
#  array([674.        ,  48.3008596 ,  51.31327603]),
#  array([675.        ,  51.09227683,  49.56870612]),
#  array([676.        ,  50.28375734,  49.91682975]),
#  array([677.        ,  49.98993964,  49.83501006]),
#  array([678.        ,  50.11287129,  48.6049505 ]),
#  array([679.        ,  49.02794411,  49.4491018 ]),
#  array([680.        ,  47.97239264,  49.17791411]),
#  array([681.        ,  50.43320236,  49.5805501 ]),
#  array([682.        ,  47.93875396,  49.12249208]),
#  array([683.        ,  49.96881288,  49.48993964]),
#  array([684.        ,  49.22392344,  48.74736842]),
#  array([685.        ,  50.07222222,  49.24537037]),
#  array([686.        ,  49.50103306,  48.05165289]),
#  array([687.        ,  50.99405352,  49.56392468]),
#  array([688.        ,  49.7996012 ,  49.94516451]),
#  array([689.        ,  48.23347107,  50.11673554]),
#  array([690.        ,  48.00522466,  49.54754441]),
#  array([691.   ,  51.616,  49.648]),
#  array([692.        ,  48.38740458,  51.50763359]),
#  array([693.        ,  50.67028628,  49.20434353]),
#  array([694.        ,  48.6522158 ,  49.82851638]),
#  array([695.        ,  51.74735729,  48.31395349]),
#  array([696.        ,  48.69315895,  51.22736419]),
#  array([697.        ,  48.71148184,  49.53385672]),
#  array([698.        ,  50.03445065,  50.52886406]),
#  array([699.        ,  47.58137155,  49.17297851]),
#  array([700.        ,  49.26622137,  51.95038168]),
#  array([701.        ,  50.94958848,  51.41666667]),
#  array([702.        ,  49.11178248,  49.40181269]),
#  array([703.        ,  49.40316206,  49.70750988]),
#  array([704.        ,  49.79324463,  49.7778915 ]),
#  array([705.        ,  48.66666667,  48.46496212]),
#  array([706.        ,  50.04334975,  49.38522167]),
#  array([707.        ,  51.15191147,  50.79778672]),
#  array([708.        ,  49.03944773,  47.56410256]),
#  array([709.        ,  48.6231003 ,  48.71935157]),
#  array([710.        ,  49.9875    ,  48.91634615]),
#  array([711.        ,  48.98463016,  48.7857829 ]),
#  array([712.        ,  49.95252226,  49.0148368 ]),
#  array([713.        ,  50.59277344,  50.1640625 ]),
#  array([714.        ,  49.23393574,  50.33634538]),
#  array([715.        ,  50.44579534,  49.78723404]),
#  array([716.        ,  48.43820225,  50.47701736]),
#  array([717.        ,  50.69658537,  48.79902439]),
#  array([718.        ,  49.08933718,  49.05379443]),
#  array([719.        ,  49.0604559 ,  50.02081269]),
#  array([720.        ,  48.17265469,  50.18063872]),
#  array([721.        ,  48.50665302,  51.01944729]),
#  array([722.        ,  49.36372745,  48.58416834]),
#  array([723.        ,  48.79365079,  51.20436508]),
#  array([724.        ,  49.58746208,  49.53892821]),
#  array([725.        ,  50.13394683,  49.75460123]),
#  array([726.        ,  49.90971541,  49.26300294]),
#  array([727.        ,  49.02840353,  50.06856024]),
#  array([728.        ,  49.6513089 ,  49.26806283]),
#  array([729.        ,  50.03556911,  51.1453252 ]),
#  array([730.        ,  49.04791667,  49.30729167]),
#  array([731.        ,  50.13693346,  48.46480231]),
#  array([732.        ,  48.60794297,  49.80753564]),
#  array([733.        ,  50.59150657,  49.04550051]),
#  array([734.        ,  51.34541793,  49.91339376]),
#  array([735.        ,  49.71938776,  49.67346939]),
#  array([736.        ,  51.17391304,  49.30724638]),
#  array([737.        ,  50.00203046,  49.59695431]),
#  array([738.        ,  48.81354269,  50.2639843 ]),
#  array([739.        ,  47.53347065,  50.6930999 ]),
#  array([740.        ,  51.31594488,  49.33070866]),
#  array([741.        ,  47.6966633 ,  51.60869565]),
#  array([742.        ,  48.38343558,  48.50613497]),
#  array([743.        ,  50.9854621 ,  51.39771547]),
#  array([744.        ,  50.36178862,  48.58638211]),
#  array([745.        ,  50.03410231,  48.69207623]),
#  array([746.        ,  49.56735497,  48.35496559]),
#  array([747.        ,  49.08023483,  49.05772994]),
#  array([748.        ,  48.315197  ,  49.80956848]),
#  array([749.        ,  48.34040404,  48.66767677]),
#  array([750.        ,  48.92437811,  51.33333333]),
#  array([751.        ,  49.85742188,  49.84863281]),
#  array([752.        ,  47.91394659,  49.92878338]),
#  array([753.        ,  50.46331658,  50.20703518]),
#  array([754.        ,  47.72301815,  49.18720153]),
#  array([755.        ,  48.92094017,  48.67735043]),
#  array([756.        ,  51.25218341,  47.33515284]),
#  array([757.   ,  50.256,  48.743]),
#  array([758.        ,  47.02962206,  48.62819203]),
#  array([759.        ,  50.90865842,  49.20837298]),
#  array([760.        ,  50.22255193,  49.15133531]),
#  array([761.        ,  50.30378486,  50.47310757]),
#  array([762.        ,  50.28484232,  50.02644964]),
#  array([763.        ,  49.78197065,  50.07861635]),
#  array([764.        ,  49.74896266,  50.80497925]),
#  array([765.        ,  49.00098135,  49.97154073]),
#  array([766.        ,  48.23404255,  49.03546099]),
#  array([767.        ,  49.87305936,  49.32328767]),
#  array([768.        ,  48.69681398,  50.17985612]),
#  array([769.        ,  50.96084656,  49.43492063]),
#  array([770.        ,  49.34872299,  48.36935167]),
#  array([771.        ,  48.20642648,  48.36806232]),
#  array([772.        ,  49.93429952,  50.84057971]),
#  array([773.        ,  48.68108652,  50.90744467]),
#  array([774.        ,  49.84725051,  49.700611  ]),
#  array([775.        ,  50.82369942,  49.43063584]),
#  array([776.        ,  49.77422577,  49.82917083]),
#  array([777.        ,  49.9857685 ,  50.47817837]),
#  array([778.        ,  49.27643979,  48.38534031]),
#  array([779.        ,  49.43398158,  50.04912999]),
#  array([780.        ,  48.37202381,  48.84623016]),
#  array([781.        ,  49.38503254,  50.38828633]),
#  array([782.        ,  49.42870999,  48.99515034]),
#  array([783.        ,  50.86454183,  49.32270916]),
#  array([784.        ,  49.59157689,  50.30166503]),
#  array([785.        ,  50.38364167,  49.63875365]),
#  array([786.        ,  49.82488038,  49.81626794]),
#  array([787.        ,  49.60963618,  48.79744346]),
#  array([788.        ,  49.75073314,  49.2913001 ]),
#  array([789.        ,  49.30661323,  49.68937876]),
#  array([790.        ,  49.82967607,  48.71159875]),
#  array([791.        ,  50.63617886,  48.73882114]),
#  array([792.        ,  49.24285714,  49.52      ]),
#  array([793.        ,  50.02888446,  48.89741036]),
#  array([794.        ,  49.17659138,  51.16427105]),
#  array([795.        ,  51.42240493,  51.97944502]),
#  array([796.        ,  49.58375635,  48.81218274]),
#  array([797.        ,  50.26970954,  48.37863071]),
#  array([798.        ,  49.97853659,  50.15317073]),
#  array([799.        ,  51.10553814,  48.78369906]),
#  array([800.        ,  50.37737738,  50.34534535]),
#  array([801.        ,  48.4835729 ,  49.02258727]),
#  array([802.        ,  49.32466181,  48.86992716]),
#  array([803.        ,  49.04360753,  49.77006938]),
#  array([804.        ,  49.56153846,  48.79807692]),
#  array([805.        ,  49.96555218,  48.73353597]),
#  array([806.        ,  49.30425963,  48.96146045]),
#  array([807.        ,  50.15142276,  48.21138211]),
#  array([808.        ,  48.82744702,  49.10090817]),
#  array([809.        ,  49.1057226 ,  50.37342386]),
#  array([810.        ,  49.49126413,  50.31449126]),
#  array([811.        ,  48.80228928,  50.4942768 ]),
#  array([812.        ,  48.391133  ,  50.06600985]),
#  array([813.        ,  49.13126253,  48.20841683]),
#  array([814.        ,  48.84778013,  48.76744186]),
#  array([815.        ,  48.59938208,  48.57775489]),
#  array([816.        ,  50.67551622,  48.83972468]),
#  array([817.        ,  51.08008008,  50.65465465]),
#  array([818.        ,  50.49621212,  49.73390152]),
#  array([819.        ,  49.10147783,  49.36157635]),
#  array([820.        ,  50.6555773 ,  47.97064579]),
#  array([821.        ,  50.43730887,  48.34352701]),
#  array([822.        ,  49.33908629,  49.28629442]),
#  array([823.        ,  48.46808511,  48.56534954]),
#  array([824.        ,  48.41970443,  49.30738916]),
#  array([825.        ,  47.57378641,  49.91359223]),
#  array([826.        ,  49.14371257,  49.73852295]),
#  array([827.        ,  49.0861244 ,  48.64497608]),
#  array([828.        ,  48.74271357,  48.94472362]),
#  array([829.        ,  49.53453453,  50.69469469]),
#  array([830.        ,  49.44422111,  50.04824121]),
#  array([831.        ,  51.1515444 ,  48.04440154]),
#  array([832.        ,  48.3227459 ,  50.03586066]),
#  array([833.        ,  49.18045862,  48.20139581]),
#  array([834.        ,  49.90899899,  47.26592518]),
#  array([835.        ,  48.93359375,  48.65917969]),
#  array([836.        ,  48.52813425,  49.12635735]),
#  array([837.        ,  49.56187625,  49.8502994 ]),
#  array([838.        ,  52.23774765,  51.50782065]),
#  array([839.        ,  49.27489627,  52.14107884]),
#  array([840.        ,  48.90853032,  50.16855087]),
#  array([841.        ,  50.31188119,  51.03564356]),
#  array([842.        ,  49.25      ,  49.69401544]),
#  array([843.        ,  50.45337302,  48.64186508]),
#  array([844.        ,  50.09813543,  47.44553484]),
#  array([845.        ,  47.31346154,  47.58269231]),
#  array([846.        ,  50.00579151,  49.31563707]),
#  array([847.        ,  48.78556701,  48.17319588]),
#  array([848.        ,  49.32714844,  48.93164062]),
#  array([849.        ,  49.61618257,  47.71161826]),
#  array([850.        ,  49.16582915,  49.97788945]),
#  array([851.        ,  51.36172345,  49.23046092]),
#  array([852.        ,  49.79816514,  49.77981651]),
#  array([853.        ,  49.13286004,  48.28296146]),
#  array([854.        ,  49.14012097,  47.64818548]),
#  array([855.        ,  48.11370558,  48.74923858]),
#  array([856.        ,  50.50571132,  50.42367601]),
#  array([857.        ,  51.04716981,  50.55031447]),
#  array([858.        ,  49.57199211,  49.77120316]),
#  array([859.        ,  48.74693878,  47.50204082]),
#  array([860.        ,  49.70081967,  50.31967213]),
#  array([861.        ,  49.19919517,  48.85915493]),
#  array([862.        ,  50.37941176,  49.99215686]),
#  array([863.        ,  50.45190381,  49.5991984 ]),
#  array([864.        ,  48.33705584,  50.55532995]),
#  array([865.        ,  50.37397541,  48.92008197]),
#  array([866.        ,  48.86064769,  49.12953876]),
#  array([867.        ,  49.525941  ,  50.36622584]),
#  array([868.        ,  48.96952381,  49.34      ]),
#  array([869.        ,  48.95721393,  50.87064677]),
#  array([870.        ,  50.0245098 ,  49.97647059]),
#  array([871.        ,  49.19246032,  48.35218254]),
#  array([872.        ,  50.42726348,  49.62156663]),
#  array([873.        ,  49.81197479,  49.8539916 ]),
#  array([874.        ,  49.56389452,  51.04563895]),
#  array([875.        ,  48.571875  ,  48.22708333]),
#  array([876.        ,  48.40744368,  50.08912831]),
#  array([877.        ,  49.24302789,  49.82370518]),
#  array([878.        ,  49.9245098 ,  49.74019608]),
#  array([879.        ,  48.6519174 ,  49.20550639]),
#  array([880.   ,  48.273,  49.357]),
#  array([881.        ,  50.29930624,  49.05153617]),
#  array([882.        ,  49.50729167,  49.95729167]),
#  array([883.        ,  50.81134021,  49.85773196]),
#  array([884.        ,  48.19037871,  49.14227226]),
#  array([885.        ,  48.79468846,  47.73340143]),
#  array([886.        ,  50.79341317,  50.46207585]),
#  array([887.        ,  49.57680872,  49.34886026]),
#  array([888.        ,  50.57200403,  48.86908359]),
#  array([889.        ,  48.76589304,  48.68314834]),
#  array([890.        ,  51.08952187,  49.44252289]),
#  array([891.        ,  50.33399801,  49.78464606]),
#  array([892.        ,  48.04448743,  50.10154739]),
#  array([893.        ,  50.09251969,  46.65059055]),
#  array([894.        ,  49.50520833,  49.14895833]),
#  array([895.        ,  48.60273973,  49.5890411 ]),
#  array([896.        ,  48.53172205,  48.82175227]),
#  array([897.        ,  50.6989899 ,  48.37171717]),
#  array([898.        ,  50.07214429,  48.71042084]),
#  array([899.        ,  48.37323944,  48.25251509]),
#  array([900.        ,  47.91370558,  49.93401015]),
#  array([901.        ,  48.79723046,  49.31256182]),
#  array([902.        ,  49.26223092,  49.44911937]),
#  array([903.        ,  48.87276342,  48.65705765]),
#  array([904.        ,  49.66833667,  48.40881764]),
#  array([905.        ,  50.45491803,  50.01229508]),
#  array([906.        ,  51.00478011,  48.2332696 ]),
#  array([907.        ,  50.37512742,  49.59938838]),
#  array([908.        ,  48.76226415,  49.64056604]),
#  array([909.        ,  49.4259962 ,  48.87191651]),
#  array([910.        ,  49.42231076,  48.89043825]),
#  array([911.        ,  51.07507508,  49.06306306]),
#  array([912.        ,  49.30745659,  49.89581205]),
#  array([913.        ,  48.60267431,  50.22636103]),
#  array([914.        ,  50.15668663,  48.64570858]),
#  array([915.        ,  48.04494382,  48.95403473]),
#  array([916.        ,  49.46853147,  49.75124875]),
#  array([917.        ,  51.77799802,  49.28344896]),
#  array([918.        ,  48.10123967,  49.3088843 ]),
#  array([919.        ,  50.03256303,  48.76260504]),
#  array([920.        ,  48.82135729,  48.15269461]),
#  array([921.        ,  48.08728448,  50.39547414]),
#  array([922.   ,  48.987,  50.111]),
#  array([923.        ,  48.71917808,  48.57827789]),
#  array([924.        ,  49.6128423 ,  50.16997167]),
#  array([925.        ,  50.52826511,  49.83528265]),
#  array([926.        ,  47.62285137,  50.00505561]),
#  array([927.        ,  48.10282258,  50.08366935]),
#  array([928.        ,  50.76960784,  50.14215686]),
#  array([929.        ,  50.20564516,  50.17237903]),
#  array([930.        ,  51.22040816,  49.91734694]),
#  array([931.        ,  48.81012658,  50.31061344]),
#  array([932.   ,  49.856,  49.581]),
#  array([933.        ,  49.7519685 ,  48.76181102]),
#  array([934.        ,  50.28156313,  48.70641283]),
#  array([935.        ,  49.18426104,  51.36948177]),
#  array([936.        ,  50.50300601,  51.34168337]),
#  array([937.        ,  48.7938247 ,  48.48904382]),
#  array([938.        ,  48.38728324,  50.73603083]),
#  array([939.        ,  50.19514661,  48.02527806]),
#  array([940.        ,  48.85433884,  49.20454545]),
#  array([941.        ,  48.94095595,  48.06091846]),
#  array([942.        ,  49.79231568,  49.34267913]),
#  array([943.        ,  48.55840164,  47.9477459 ]),
#  array([944.        ,  49.70893971,  48.72037422]),
#  array([945.        ,  49.60714286,  49.33829365]),
#  array([946.        ,  48.92413793,  49.31428571]),
#  array([947.        ,  49.20472441,  48.62204724]),
#  array([948.        ,  48.8125    ,  50.28629032]),
#  array([949.        ,  49.71935157,  49.76899696]),
#  array([950.        ,  48.90634441,  50.07452165]),
#  array([951.        ,  49.41158537,  49.08231707]),
#  array([952.        ,  49.05381605,  50.24266145]),
#  array([953.        ,  50.29153269,  48.53483387]),
#  array([954.        ,  48.22336066,  48.57786885]),
#  array([955.        ,  49.87209302,  49.43023256]),
#  array([956.        ,  49.42436548,  49.76243655]),
#  array([957.        ,  49.41997961,  50.39041794]),
#  array([958.        ,  49.7374359 ,  49.89025641]),
#  array([959.        ,  48.36647727,  47.57102273]),
#  array([960.        ,  50.42916236,  48.37021717]),
#  array([961.        ,  49.44834504,  48.34603811]),
#  array([962.        ,  48.23157895,  47.96      ]),
#  array([963.        ,  49.21703011,  48.61578401]),
#  array([964.   ,  50.22 ,  48.606]),
#  array([965.        ,  49.41919192,  47.80909091]),
#  array([966.        ,  48.34393638,  47.86978131]),
#  array([967.        ,  49.08619001,  49.3927522 ]),
#  array([968.        ,  48.65212876,  50.14953271]),
#  array([969.        ,  49.27693857,  49.83182276]),
#  array([970.        ,  50.15581854,  49.51282051]),
#  array([971.        ,  50.83489097,  48.98234683]),
#  array([972.        ,  50.2266055 ,  49.64311927]),
#  array([973.        ,  48.00998004,  48.75948104]),
#  array([974.        ,  50.41727367,  49.84495317]),
#  array([975.        ,  50.44985394,  50.08763389]),
#  array([976.        ,  50.37206932,  48.71763507]),
#  array([977.        ,  49.11812627,  50.00610998]),
#  array([978.        ,  48.13944223,  49.06573705]),
#  array([979.        ,  49.93625498,  50.62350598]),
#  array([980.        ,  49.5509434 ,  49.47830189]),
#  array([981.        ,  49.69030969,  48.95504496]),
#  array([982.        ,  48.84321608,  48.38693467]),
#  array([983.        ,  49.85053038,  48.91224687]),
#  array([984.        ,  48.83840304,  48.84505703]),
#  array([985.        ,  50.59742829,  50.00395648]),
#  array([986.        ,  48.53099174,  50.94214876]),
#  array([987.        ,  49.2324159 ,  49.18042813]),
#  array([988.        ,  50.0259481 ,  49.75149701]),
#  array([989.        ,  48.77855015,  49.73286991]),
#  array([990.        ,  49.82334385,  49.24815983]),
#  array([991.        ,  49.56846473,  48.49170124]),
#  array([992.        ,  48.59580838,  48.23752495]),
#  array([993.        ,  49.38263359,  49.92080153]),
#  array([994.        ,  49.56767677,  51.6989899 ]),
#  array([995.        ,  48.63956905,  49.23212537]),
#  array([996.        ,  49.98138573,  50.07755946]),
#  array([997.        ,  49.6749503 ,  48.70377734]),
#  array([998.        ,  49.17613636,  48.57291667]),
#  array([999.        ,  50.53006475,  49.81776133]),
#  ...]

# %%
temp = pd.DataFrame(temp, columns=['category', 'A', 'B'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# D:\Anaconda3\envs\standard\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     567     try:
# --> 568         columns = _validate_or_indexify_columns(content, columns)
#     569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#
# D:\Anaconda3\envs\standard\lib\site-packages\pandas\core\internals\construction.py in _validate_or_indexify_columns(content, columns)
#     692             raise AssertionError(
# --> 693                 f"{len(columns)} columns passed, passed data had "
#     694                 f"{len(content)} columns"
#
# AssertionError: 3 columns passed, passed data had 2 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-43600fc8b904> in <module>
# ----> 1 temp = pd.DataFrame(temp, columns=['category', 'A', 'B'])
#
# D:\Anaconda3\envs\standard\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     568                     if is_named_tuple(data[0]) and columns is None:
#     569                         columns = data[0]._fields
# --> 570                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     571                     columns = ensure_index(columns)
#     572
#
# D:\Anaconda3\envs\standard\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     550         # last ditch effort
#     551         data = [tuple(x) for x in data]
# --> 552         return _list_to_arrays(data, columns, coerce_float=coerce_float, dtype=dtype)
#     553
#     554
#
# D:\Anaconda3\envs\standard\lib\site-packages\pandas\core\internals\construction.py in _list_to_arrays(data, columns, coerce_float, dtype)
#     569         result = _convert_object_array(content, dtype=dtype, coerce_float=coerce_float)
#     570     except AssertionError as e:
# --> 571         raise ValueError(e) from e
#     572     return result, columns
#     573
#
# ValueError: 3 columns passed, passed data had 2 columns

# %%
temp['category'] = temp['category'].astype('int64')

# %%
temp.head()

# %%
# %%time
temp2 = df.groupby('category')[['A', 'B']].apply(lambda x: np.mean(x, axis=0))
temp2 = temp2.reset_index()
# Out:
# Wall time: 9.35 s

# %%
temp2.head()
# Out:
#    category          A          B
# 0         0  49.803209  51.578610
# 1         1  49.770771  50.954955
# 2         2  48.668302  50.244357
# 3         3  49.009960  48.709163
# 4         4  48.510660  48.421320

# %%
pd.testing.assert_frame_equal(temp, temp2)

# %%
first_category = np.random.choice(n_categories, n_obs)
np.random.seed(2016)
y = np.random.normal(0, 1, n_obs)

# %%
len(np.unique(first_category))
# Out:
# 10000

# %%
len(first_category)
# Out:
# 10000000

# %%
y
# Out:
# array([ 0.29485409,  0.50803768,  0.7047403 , ...,  0.27281381,
#         0.60083149, -1.25487632])

# %%
unique_keys, indices = np.unique(['a', 'b', 'a', 'a', 'b'], return_inverse = True)
# array([{'b', 'a'}], dtype=object)
print(unique_keys) 
# [0, 1, 0, 0, 1]
print(indices) 
# array(['a', 'b', 'a', 'a', 'b'], dtype='<U1')
print(unique_keys[indices])
# Out:
# ['a' 'b']
# [0 1 0 0 1]
# ['a' 'b' 'a' 'a' 'b']

# %%
start = timeit.timeit()
grouped = Groupby(first_category)

group_means = Groupby(first_category).apply(np.mean, y, broadcast=False)
print('time to compute group means once with Grouped: {0}'\
      .format(round(timeit.timeit() - start, n_decimals)))

start = timeit.timeit()
grouped = Groupby(first_category)
for i in range(n_iters):
    grouped.apply(np.mean, y, broadcast=False)
    
print('time to compute group means {0} times with Grouped: {1}'\
      .format(n_iters, timeit.timeit()-start, n_decimals))
# Out:
# time to compute group means once with Grouped: -0.007
# time to compute group means 100 times with Grouped: 0.0022116999999752807
